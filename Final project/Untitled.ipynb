# %% [markdown]
# ### 서울시 날씨 api 연동

# %%
import requests

# %%
def get_weather(api_key, location):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={location}&appid={api_key}&lang=kr&units=metric"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        weather = {
            "location": data["name"],
            "temperature": data["main"]["temp"],
            "feels_like": data["main"]["feels_like"],
            "temp_min": data["main"]["temp_min"],
            "temp_max": data["main"]["temp_max"],
            "pressure": data["main"]["pressure"],
            "humidity": data["main"]["humidity"],
            "weather_description": data["weather"][0]["description"],
            "wind_speed": data["wind"]["speed"],
            "wind_deg": data["wind"]["deg"]
        }
        return weather
    else:
        return f"Error: Unable to fetch weather data (Status code: {response.status_code})"

def recommend_food(weather):
    temperature = weather["temperature"]
    description = weather["weather_description"]
    
    if temperature > 30:
        return "더운 날씨에는 시원한 냉면이나 아이스크림을 추천합니다!"
    elif temperature > 20:
        return "따뜻한 날씨에는 가벼운 샐러드나 과일 주스를 추천합니다!"
    elif temperature > 10:
        return "선선한 날씨에는 국물 요리나 따뜻한 차를 추천합니다!"
    else:
        return "추운 날씨에는 따뜻한 국물 요리나 커피를 추천합니다!"

# API 키를 여기에 입력하세요
api_key = 'bd3c9711037a63b12688f8c555eb5593'

seoul_districts = [
    ("Gangnam-gu,Seoul,KR", "서울시 강남구"), ("Gangdong-gu,Seoul,KR", "서울시 강동구"), ("Gangbuk-gu,Seoul,KR", "서울시 강북구"), 
    ("Gangseo-gu,Seoul,KR", "서울시 강서구"), ("Gwanak-gu,Seoul,KR", "서울시 관악구"), ("Gwangjin-gu,Seoul,KR", "서울시 광진구"), 
    ("Guro-gu,Seoul,KR", "서울시 구로구"), ("Geumcheon-gu,Seoul,KR", "서울시 금천구"), ("Nowon-gu,Seoul,KR", "서울시 노원구"), 
    ("Dobong-gu,Seoul,KR", "서울시 도봉구"), ("Dongdaemun-gu,Seoul,KR", "서울시 동대문구"), ("Dongjak-gu,Seoul,KR", "서울시 동작구"), 
    ("Mapo-gu,Seoul,KR", "서울시 마포구"), ("Seodaemun-gu,Seoul,KR", "서울시 서대문구"), ("Seocho-gu,Seoul,KR", "서울시 서초구"), 
    ("Seongdong-gu,Seoul,KR", "서울시 성동구"), ("Seongbuk-gu,Seoul,KR", "서울시 성북구"), ("Songpa-gu,Seoul,KR", "서울시 송파구"), 
    ("Yangcheon-gu,Seoul,KR", "서울시 양천구"), ("Yeongdeungpo-gu,Seoul,KR", "서울시 영등포구"), ("Yongsan-gu,Seoul,KR", "서울시 용산구"), 
    ("Eunpyeong-gu,Seoul,KR", "서울시 은평구"), ("Jongno-gu,Seoul,KR", "서울시 종로구"), ("Jung-gu,Seoul,KR", "서울시 중구"), 
    ("Jungnang-gu,Seoul,KR", "서울시 중랑구")
]

# 사용자가 행정구를 선택하도록 함
print("서울시 행정구 목록:")
for i, (district_eng, district_kor) in enumerate(seoul_districts, 1):
    print(f"{i}. {district_kor}")

choice = int(input("날씨 정보를 확인할 행정구의 번호를 선택하세요: "))
selected_location = seoul_districts[choice - 1][0]

# 선택한 행정구의 날씨 정보 가져오기
weather_info = get_weather(api_key, selected_location)

if isinstance(weather_info, dict):
    food_recommendation = recommend_food(weather_info)
    print(f"위치: {seoul_districts[choice - 1][1]}")
    print(f"현재 온도: {weather_info['temperature']}°C")
    print(f"체감 온도: {weather_info['feels_like']}°C")
    print(f"최저 온도: {weather_info['temp_min']}°C")
    print(f"최고 온도: {weather_info['temp_max']}°C")
    print(f"기압: {weather_info['pressure']} hPa")
    print(f"습도: {weather_info['humidity']}%")
    print(f"날씨 설명: {weather_info['weather_description']}")
    print(f"풍속: {weather_info['wind_speed']} m/s")
    print(f"풍향: {weather_info['wind_deg']}°")
    print(f"추천 음식: {food_recommendation}")
else:
    print("날씨 정보를 가져올 수 없습니다.")
# Out:
# 서울시 행정구 목록:
# 1. 강남구
# 2. 강동구
# 3. 강북구
# 4. 강서구
# 5. 관악구
# 6. 광진구
# 7. 구로구
# 8. 금천구
# 9. 노원구
# 10. 도봉구
# 11. 동대문구
# 12. 동작구
# 13. 마포구
# 14. 서대문구
# 15. 서초구
# 16. 성동구
# 17. 성북구
# 18. 송파구
# 19. 양천구
# 20. 영등포구
# 21. 용산구
# 22. 은평구
# 23. 종로구
# 24. 중구
# 25. 중랑구
# 날씨 정보를 확인할 행정구의 번호를 선택하세요:  14
# 위치: 서대문구
# 현재 온도: 28.65°C
# 체감 온도: 29°C
# 최저 온도: 26.69°C
# 최고 온도: 28.76°C
# 기압: 1013 hPa
# 습도: 48%
# 날씨 설명: 맑음
# 풍속: 1.54 m/s
# 풍향: 300°
# 추천 음식: 따뜻한 날씨에는 가벼운 샐러드나 과일 주스를 추천합니다!

# %% [markdown]
# ### 네이버 블로그 api 연동

# %%
rainy_day_foods = [
    "파전", "김치찌개", "부침개", "라면", "순대국", "삼계탕", "떡볶이", "우동", "칼국수", "전골",
    "감자전", "김치전", "해물파전", "짜장면", "짬뽕", "감자탕", "순두부찌개", "된장찌개", "고등어조림", "갈비탕",
    "설렁탕", "육개장", "닭볶음탕", "오뎅탕", "매운탕", "아귀찜", "백숙", "수제비", "콩나물국밥", "북엇국",
    "미역국", "도가니탕", "대구탕", "김밥", "비빔밥", "잡채", "갈비찜", "족발", "보쌈", "떡국",
    "만둣국", "어묵", "부대찌개", "곰탕", "청국장찌개", "제육볶음", "닭갈비", "곱창전골", "닭한마리", "오징어볶음",
    "낙지볶음", "양념게장", "간장게장", "감자수제비", "버섯전골", "두부김치", "호박전", "동태찌개", "오삼불고기", "참치김치찌개",
    "비지찌개", "갈치조림", "된장국", "쭈꾸미볶음", "숯불갈비", "꽁치조림", "닭곰탕", "닭죽", "장어구이", "매운갈비찜",
    "홍합탕", "매운오징어볶음", "알탕", "두루치기", "고추장찌개", "오리주물럭", "민어탕", "동태전", "명란젓", "북어찜",
    "보리밥", "콩국수", "황태해장국", "메밀전병", "칼비빔국수", "수육", "닭도리탕", "아구탕", "모둠전", "김치볶음밥",
    "굴국밥", "동치미국수", "고추장불고기", "닭안심찜", "새우튀김", "미나리무침", "어묵볶음", "버섯볶음", "멸치볶음", "가지볶음"
]

# %%
import requests
from bs4 import BeautifulSoup
from konlpy.tag import Okt
from collections import Counter
import pandas as pd

# 네이버 API 인증 정보
client_id = 'JUIsxNlObCc7b3BCqWe1'
client_secret = 'pqVF4o6iit'

def get_blog_content(query, display):
    url = f"https://openapi.naver.com/v1/search/blog?query={query}&display={display}&sort=sim"
    headers = {
        "X-Naver-Client-Id": client_id,
        "X-Naver-Client-Secret": client_secret
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()['items']
    else:
        print("Error Code:", response.status_code)
        return None

def extract_food_names(text_list):
    okt = Okt()
    all_nouns = []

    for text in text_list:
        nouns = okt.nouns(text)
        all_nouns.extend(nouns)
    
    # 음식과 관련된 단어를 필터링합니다.
    foods = [noun for noun in all_nouns if len(noun) > 1]
    food_names = [name for name in foods if name in rainy_day_foods]
    
    return food_names

def main():
    query = '비오는 날 음식'
    blog_posts = get_blog_content(query, 100)
    
    if not blog_posts:
        return None
    
    all_text = []
    
    for post in blog_posts:
        title = post['title']
        description = post['description']
        soup = BeautifulSoup(title + ' ' + description, 'html.parser')
        text = soup.get_text()
        all_text.append(text)
    
    food_names = extract_food_names(all_text)
    
    food_counter = Counter(food_names)
    
    # 데이터 프레임 생성
    food_df = pd.DataFrame(food_counter.items(), columns=['Food', 'Count'])
    
    return food_df

if __name__ == "__main__":
    food_df = main()
    if food_df is not None:
        print(food_df)
# Out:
#     Food  Count
# 0     어묵      8
# 1     우동     10
# 2    된장국      2
# 3   해물파전     18
# 4     파전     14
# 5    감자전     17
# 6    부침개     38
# 7    수제비     32
# 8   두부김치      1
# 9    칼국수     11
# 10   짜장면      2
# 11    짬뽕      3
# 12    곰탕      2
# 13   김치전     24
# 14    라면      2
# 15   갈비찜      1
# 16  김치찌개      1
# 17   삼계탕      1
# 18   닭갈비      2

# %%
import requests
from bs4 import BeautifulSoup
from konlpy.tag import Okt
from collections import Counter
import pandas as pd

# 네이버 API 인증 정보
client_id = 'JUIsxNlObCc7b3BCqWe1'
client_secret = 'pqVF4o6iit'

def get_blog_content(query, display):
    url = f"https://openapi.naver.com/v1/search/blog?query={query}&display={display}&sort=sim"
    headers = {
        "X-Naver-Client-Id": client_id,
        "X-Naver-Client-Secret": client_secret
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()['items']
    else:
        print("Error Code:", response.status_code)
        return None

def extract_food_names(text_list):
    okt = Okt()
    all_nouns = []

    for text in text_list:
        nouns = okt.nouns(text)
        all_nouns.extend(nouns)
    
    # 음식과 관련된 단어를 필터링합니다.
    foods = [noun for noun in all_nouns if len(noun) > 1]
    # food_names = [name for name in foods if name in rainy_day_foods]

def main():
    query = '비오는 날 음식'
    blog_posts = get_blog_content(query, 100)
    
    if not blog_posts:
        return None
    
    all_text = []
    
    for post in blog_posts:
        title = post['title']
        description = post['description']
        soup = BeautifulSoup(title + ' ' + description, 'html.parser')
        text = soup.get_text()
        all_text.append(text)
    
    food_names = extract_food_names(all_text)
    
    food_counter = Counter(food_names)
    
    # 데이터 프레임 생성
    food_df = pd.DataFrame(food_counter.items(), columns=['Food', 'Count'])
    
    return food_df

if __name__ == "__main__":
    food_df = main()
    if food_df is not None:
        print(food_df)
# Out:
# Empty DataFrame
# Columns: [Food, Count]
# Index: []

# %%
food_df.sort_values(by='Count', ascending=False).Food.unique()
# Out:
# array(['음식', '추천', '맛집', '쭈꾸미', '키트', '국밥', '볶음', '캠핑', '부산', '실비', '게장',
#        '스트레스', '갈비', '닭발', '메뉴', '만두', '오뎅', '돼지국밥', '오늘', '요리', '매운갈비찜',
#        '본점', '서면', '집들이', '건대', '양념', '불만', '꽃게', '매콤', '김치', '감자탕',
#        '갈비찜', '냉동', '어묵', '레시피', '불닭', '진짜', '술안주', '부분식', '고집', '날개',
#        '동백', '모두', '주문', '집밥', '청주', '정말', '요즘', '낙지', '힐링', '김밥', '완전',
#        '만들기', '도전', '도사', '정도', '전주', '크레이지', '자주', '리뷰', '짚신', '고기',
#        '라면', '홍대', '쌀국수', '후기', '제로', '군자', '국물', '점심', '떡볶이', '수원', '광주',
#        '위치', '조리', '친구', '강력', '식당', '불콩', '돼지', '제품', '유튜브', '닭갈비', '계란',
#        '낙곱새', '여기', '해장국', '조호', '배달', '팽이버섯', '엽기', '그냥', '이용', '우리',
#        '조합', '안산', '아구찜', '냉면', '손님', '수완', '모음', '시간', '영업', '피크닉', '치킨',
#        '매일유업', '포스팅', '숙대', '고수', '쭈곱새', '가격', '냄새', '한식', '기분', '손질',
#        '파김치', '외국인', '주먹밥', '행신동', '밥집', '삿포로', '일본', '카카', '모츠', '골목',
#        '반찬', '소갈비찜', '소주', '제대로', '도둑', '동명동', '방문', '코다리', '중독', '곱창',
#        '전통주', '한국', '보관', '양도', '공화춘', '고민', '무뼈', '세트', '연희동', '불스',
#        '아주', '소스', '신분', '자극', '알고싶다', '주꾸미', '처음', '동래', '안주', '편의점',
#        '가끔', '임큐', '방법', '역대', '술집', '보양', '창동', '제철', '닭볶음탕', '러버', '얼마',
#        '블로거', '다이어트', '고추', '땡초', '순두부', '음식점', '추가', '볶이', '가득', '짜장',
#        '콩나물', '동생', '미사', '검색', '선화동', '혁신도시', '보시', '고이', '살짝', '매움',
#        '주의', '얼마나', '야식', '폭탄', '잠실', '방이', '백석역', '북적', '더욱', '녹양동',
#        '과일', '월피동', '전설', '워낙', '쉑쉑', '제일', '감기', '부평', '조호바루', '택배',
#        '살이', '신사', '우물', '금지', '하나', '궁합', '소면', '지금', '분덜', '직화', '위해',
#        '둘이서', '먹기', '하루', '청자', '평소', '미미', '공원', '호수', '천호역', '주둥이',
#        '동동', '창원', '소개', '친자', '기준', '스푼', '활용', '여행', '고춧가루', '청양', '때문',
#        '캐리', '오징어', '이상', '지구', '시작', '직원', '망원동', '수육', '덕후', '매운불스',
#        '월순', '테이블', '캠핑장', '서울대', '가장', '무엇', '가지', '베스트', '전화번호', '한번',
#        '동태', '사이', '로제불스', '철판', '보기', '매니아', '아이템', '데이트', '사진', '바로',
#        '구매', '주차장', '땀땀', '기름', '매우', '매일', '베트남', '식사', '저희', '복숭아',
#        '강추', '화등', '개인', '후라이드', '삼이', '먼저', '보통', '무려', '준비', '천안', '화초',
#        '기본', '비빔밥', '예전', '피스', '소사', '신제품', '고역', '사람', '는걸', '전문점',
#        '번호', '머리', '만이', '꼬치', '다른', '토담집', '만성', '대표', '기지', '전체', '나이',
#        '방송', '여부', '손색', '제공', '해먹', '서비스', '업체', '노트', '도움', '정표', '상세',
#        '트렌드', '판단', '시장', '주류', '막걸리', '일품', '누가', '일단', '한국인', '구입',
#        '작성', '정이', '뿌뿌', '주가', '메뉴인', '마니아', '일산', '보심', '신지', '타지', '돌뼈',
#        '어가', '푸드', '세상', '피해', '헤헤', '아이스박스', '아이스팩', '중구', '해소', '생각',
#        '대전', '회관', '선화', '기부', '요거트', '황금', '정보', '소주잔', '사은', '햄찌', '사용',
#        '말레이시아', '삼발', '요기', '서로', '단골', '최애', '지난', '기만', '에코', '출처',
#        '여러분', '메이', '우유', '팅해', '강동', '명절', '애청', '신상', '엽떡', '보신', '복자',
#        '접대', '이웃', '조리법', '프라이팬', '불로', '에어', '프라이어', '입안', '사우동', '비빔국수',
#        '연일', '다소', '나물', '계시', '주제', '종일', '신경', '일도', '표시', '매장', '보고',
#        '맛좀', '해도', '사케', '잇님들', '예술', '산남동', '광고', '직영', '끝장', '천호동',
#        '부추', '불판', '뽀샤장', '초콜렛', '뭔들', '이유', '지도', '적극', '분위기', '진보',
#        '평상시', '따라서', '접근', '명물', '만족', '신길동', '발견', '짬뽕', '순삭', '서현역',
#        '오빠', '신대방동', '돈까스', '격하', '연동', '제주도', '삼삼오오', '와우', '인천', '구이',
#        '사시', '중앙', '식신', '상부', '명실', '유지', '신선도', '급랭', '세척', '최상급',
#        '해물찜', '꽃게탕', '원조', '박사', '반주', '자랑', '사랑', '공영', '근처', '별도', '주말',
#        '순환로', '남부', '관악구', '서울시', '입구', '단계', '밑반찬', '중화', '필수', '야장',
#        '도리', '노원역', '뭔가', '짜조', '프리미엄', '가능', '직관', '소고기', '숯불', '강남역',
#        '이외', '우소', '꿀팁', '일본여행', '징유', '주변', '경찰서', '부산진', '청춘', '달리',
#        '매달', '크게', '독도', '홈파티', '평일', '비빔', '스타일', '편이', '야외', '출구',
#        '전포역', '건물', '양장', '미림', '화랑', '고추장', '그것', '청양고추', '행사', '맥주',
#        '이벤트', '홍솜', '의사', '사장', '원곡동', '동치미', '조금', '신라면', '최고', '순위',
#        '버전', '바게트', '기존', '버터', '소금', '사이드', '제스', '솔직', '핫반', '후반', '입술',
#        '발라', '살로', '축하', '컵라면', '유튜버들', '야끼소바', '유튜버', '종종', '포점', '불스지',
#        '날씨', '안성맞춤', '혼술족', '한신포차', '스토', '느낌', '개수', '냉장', '줄줄', '납작',
#        '오리', '퀄리티', '맛깔', '노력', '혹시', '강변', '오시', '대명사', '양념감자', '롯데리아',
#        '콧물', '체크', '탄수화물', '족발', '찜닭', '불고기', '운지', '관광객', '번길', '선로',
#        '영통구', '수원시', '경기', '부심', '정신', '당면', '맛불콩', '면서', '지옥', '대박',
#        '매력', '비빔면', '잔치', '엄궁', '영혼', '관심', '나라', '현지', '선택', '요새', '문의',
#        '가맹', '헬로', '이번', '재료', '해결', '선사', '희소식', '전하', '불콩뼈', '선생', '아이',
#        '두번째', '마무리', '뻘뻘', '안녕', '몸살', '꾸욱', '하니', '데친', '깻잎', '가위', '번의',
#        '줄기', '우선', '배추', '국내', '종류', '삼겹살', '공기', '굿굿', '쌀밥', '사이즈', '노원',
#        '설명', '셀프', '리필', '꼬들하', '코스', '가기', '음료', '끼리', '어른', '대감', '왕뽈찜',
#        '작전동', '뼈찜', '묵은지', '도장', '댓글', '공감', '메뉴판', '회식', '부평역', '인위',
#        '잔뜩', '호기심', '직접', '음료수', '여름', '남자', '제시', '나들이', '찰떡', '링크'],
#       dtype=object)

# %%
import pandas as pd

data = pd.read_csv('data/식품의약품안전처_통합식품영양성분정보(음식)_20240416.csv', encoding='CP949')
data.head(3)
# Out:
#                   식품코드                 식품명 데이터구분코드 데이터구분명  식품기원코드  \
# 0  D219-711000000-0287  아이스크림_프릳츠 커피 아이스크림       D     음식       2
# 1  D303-148000000-0001   라면_간편조리세트_똠양꿍요괴라면       D     음식       3
# 2  D101-004160000-0001             국밥_돼지머리       D     음식       1
#
#                     식품기원명  식품대분류코드      식품대분류명  대표식품코드  대표식품명  ...  포화지방산(g)  \
# 0  외식(프랜차이즈 등 업체 제공 영양정보)       19  유제품류 및 빙과류   19711  아이스크림  ...      6.09
# 1                외식(분석함량)        3     면 및 만두류    3148     라면  ...      1.35
# 2              가정식(분석 함량)        1          밥류    1004     국밥  ...      1.47
#
#   트랜스지방산(g)  출처코드       출처명   식품중량          업체명 데이터생성방법코드  데이터생성방법명  \
# 0      0.00     3  식품의약품안전처   115g       배스킨라빈스         2        수집
# 1      0.01     3  식품의약품안전처  1284g  GS 리테일 심플리쿡         1        분석
# 2      0.03     3  식품의약품안전처   900g         해당없음         1        분석
#
#       데이터생성일자     데이터기준일자
# 0  2023-10-31  2024-04-16
# 1  2022-06-30  2024-04-16
# 2  2017-12-31  2024-04-16
#
# [3 rows x 49 columns]

# %%
len(data['식품명'].tolist())
# Out:
# 12151

# %%
import requests
from bs4 import BeautifulSoup
from konlpy.tag import Okt
from collections import Counter
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from concurrent.futures import ThreadPoolExecutor
import time

# 네이버 API 인증 정보
client_id = 'JUIsxNlObCc7b3BCqWe1'
client_secret = 'pqVF4o6iit'

def get_blog_content(query, display):
    url = f"https://openapi.naver.com/v1/search/blog?query={query}&display={display}&sort=sim"
    headers = {
        "X-Naver-Client-Id": client_id,
        "X-Naver-Client-Secret": client_secret
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()['items']
    else:
        print("Error Code:", response.status_code)
        return None

def extract_food_names(text_list):
    okt = Okt()
    all_nouns = []

    for text in text_list:
        nouns = okt.nouns(text)
        all_nouns.extend(nouns)
    
    # 음식과 관련된 단어를 필터링합니다.
    food_names = [noun for noun in all_nouns if len(noun) > 1]
    
    return food_names

def fetch_and_extract_text(post):
    title = post['title']
    description = post['description']
    soup = BeautifulSoup(title + ' ' + description, 'html.parser')
    return soup.get_text()

def main():
    start_time = time.time()
    query = '매운 음식추천'
    blog_posts = get_blog_content(query, 100)
    
    if not blog_posts:
        return None
    
    with ThreadPoolExecutor() as executor:
        all_text = list(executor.map(fetch_and_extract_text, blog_posts))
    
    food_names = extract_food_names(all_text)
    
    food_counter = Counter(food_names)
    food_df = pd.DataFrame(food_counter.items(), columns=['Food', 'Count'])
    
    # 음식 메뉴 데이터
    menu_data = data['식품명'].tolist()  # 예시 데이터입니다. 실제 데이터로 대체하세요.

    # TF-IDF 벡터라이저를 사용하여 메뉴 데이터를 벡터화
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(menu_data)

    # 블로그 텍스트에서 명사 추출
    blog_text = " ".join(food_names)
    blog_tfidf = vectorizer.transform([blog_text])

    # CPU 코어 수에 맞게 병렬 처리
    with ThreadPoolExecutor() as executor:
        cosine_similarities = list(executor.map(lambda i: cosine_similarity(blog_tfidf, tfidf_matrix[i:i+1]).flatten()[0], range(len(menu_data))))

    # 유사도가 높은 명사 필터링 (임계값 설정, 여기서는 0.3로 설정)
    threshold = 0.3
    similar_nouns = [menu_data[i] for i in range(len(cosine_similarities)) if cosine_similarities[i] > threshold]

    # 유사한 명사들만 포함하는 데이터프레임 생성
    similar_food_df = food_df[food_df['Food'].isin(similar_nouns)]

    print("유사한 명사들로 구성된 데이터프레임:")
    print(similar_food_df)

    print(f"Execution time: {time.time() - start_time} seconds")
    return similar_food_df

if __name__ == "__main__":
    similar_food_df = main()
    if similar_food_df is not None:
        print(similar_food_df)
# Out:
# 유사한 명사들로 구성된 데이터프레임:
#     Food  Count
# 224  쌀국수      5
# 238   김밥      7
# 288   국밥     21
# 310   라면      5
# 335  감자탕     10
# 355  떡볶이      5
# Execution time: 27.561728477478027 seconds
#     Food  Count
# 224  쌀국수      5
# 238   김밥      7
# 288   국밥     21
# 310   라면      5
# 335  감자탕     10
# 355  떡볶이      5

# %%
similar_food_df.sort_values(by='Count', ascending=False)
# Out:
#     Food  Count
# 288   국밥     21
# 335  감자탕     10
# 238   김밥      7
# 224  쌀국수      5
# 310   라면      5
# 355  떡볶이      5

# %%
food_df.sort_values(by='Count', ascending=False).Food.unique()
# Out:
# array(['음식', '추천', '맛집', '쭈꾸미', '키트', '국밥', '볶음', '캠핑', '부산', '실비', '게장',
#        '스트레스', '갈비', '닭발', '메뉴', '만두', '오뎅', '돼지국밥', '오늘', '요리', '매운갈비찜',
#        '본점', '서면', '집들이', '건대', '양념', '불만', '꽃게', '매콤', '김치', '감자탕',
#        '갈비찜', '냉동', '어묵', '레시피', '불닭', '진짜', '술안주', '부분식', '고집', '날개',
#        '동백', '모두', '주문', '집밥', '청주', '정말', '요즘', '낙지', '힐링', '김밥', '완전',
#        '만들기', '도전', '도사', '정도', '전주', '크레이지', '자주', '리뷰', '짚신', '고기',
#        '라면', '홍대', '쌀국수', '후기', '제로', '군자', '국물', '점심', '떡볶이', '수원', '광주',
#        '위치', '조리', '친구', '강력', '식당', '불콩', '돼지', '제품', '유튜브', '닭갈비', '계란',
#        '낙곱새', '여기', '해장국', '조호', '배달', '팽이버섯', '엽기', '그냥', '이용', '우리',
#        '조합', '안산', '아구찜', '냉면', '손님', '수완', '모음', '시간', '영업', '피크닉', '치킨',
#        '매일유업', '포스팅', '숙대', '고수', '쭈곱새', '가격', '냄새', '한식', '기분', '손질',
#        '파김치', '외국인', '주먹밥', '행신동', '밥집', '삿포로', '일본', '카카', '모츠', '골목',
#        '반찬', '소갈비찜', '소주', '제대로', '도둑', '동명동', '방문', '코다리', '중독', '곱창',
#        '전통주', '한국', '보관', '양도', '공화춘', '고민', '무뼈', '세트', '연희동', '불스',
#        '아주', '소스', '신분', '자극', '알고싶다', '주꾸미', '처음', '동래', '안주', '편의점',
#        '가끔', '임큐', '방법', '역대', '술집', '보양', '창동', '제철', '닭볶음탕', '러버', '얼마',
#        '블로거', '다이어트', '고추', '땡초', '순두부', '음식점', '추가', '볶이', '가득', '짜장',
#        '콩나물', '동생', '미사', '검색', '선화동', '혁신도시', '보시', '고이', '살짝', '매움',
#        '주의', '얼마나', '야식', '폭탄', '잠실', '방이', '백석역', '북적', '더욱', '녹양동',
#        '과일', '월피동', '전설', '워낙', '쉑쉑', '제일', '감기', '부평', '조호바루', '택배',
#        '살이', '신사', '우물', '금지', '하나', '궁합', '소면', '지금', '분덜', '직화', '위해',
#        '둘이서', '먹기', '하루', '청자', '평소', '미미', '공원', '호수', '천호역', '주둥이',
#        '동동', '창원', '소개', '친자', '기준', '스푼', '활용', '여행', '고춧가루', '청양', '때문',
#        '캐리', '오징어', '이상', '지구', '시작', '직원', '망원동', '수육', '덕후', '매운불스',
#        '월순', '테이블', '캠핑장', '서울대', '가장', '무엇', '가지', '베스트', '전화번호', '한번',
#        '동태', '사이', '로제불스', '철판', '보기', '매니아', '아이템', '데이트', '사진', '바로',
#        '구매', '주차장', '땀땀', '기름', '매우', '매일', '베트남', '식사', '저희', '복숭아',
#        '강추', '화등', '개인', '후라이드', '삼이', '먼저', '보통', '무려', '준비', '천안', '화초',
#        '기본', '비빔밥', '예전', '피스', '소사', '신제품', '고역', '사람', '는걸', '전문점',
#        '번호', '머리', '만이', '꼬치', '다른', '토담집', '만성', '대표', '기지', '전체', '나이',
#        '방송', '여부', '손색', '제공', '해먹', '서비스', '업체', '노트', '도움', '정표', '상세',
#        '트렌드', '판단', '시장', '주류', '막걸리', '일품', '누가', '일단', '한국인', '구입',
#        '작성', '정이', '뿌뿌', '주가', '메뉴인', '마니아', '일산', '보심', '신지', '타지', '돌뼈',
#        '어가', '푸드', '세상', '피해', '헤헤', '아이스박스', '아이스팩', '중구', '해소', '생각',
#        '대전', '회관', '선화', '기부', '요거트', '황금', '정보', '소주잔', '사은', '햄찌', '사용',
#        '말레이시아', '삼발', '요기', '서로', '단골', '최애', '지난', '기만', '에코', '출처',
#        '여러분', '메이', '우유', '팅해', '강동', '명절', '애청', '신상', '엽떡', '보신', '복자',
#        '접대', '이웃', '조리법', '프라이팬', '불로', '에어', '프라이어', '입안', '사우동', '비빔국수',
#        '연일', '다소', '나물', '계시', '주제', '종일', '신경', '일도', '표시', '매장', '보고',
#        '맛좀', '해도', '사케', '잇님들', '예술', '산남동', '광고', '직영', '끝장', '천호동',
#        '부추', '불판', '뽀샤장', '초콜렛', '뭔들', '이유', '지도', '적극', '분위기', '진보',
#        '평상시', '따라서', '접근', '명물', '만족', '신길동', '발견', '짬뽕', '순삭', '서현역',
#        '오빠', '신대방동', '돈까스', '격하', '연동', '제주도', '삼삼오오', '와우', '인천', '구이',
#        '사시', '중앙', '식신', '상부', '명실', '유지', '신선도', '급랭', '세척', '최상급',
#        '해물찜', '꽃게탕', '원조', '박사', '반주', '자랑', '사랑', '공영', '근처', '별도', '주말',
#        '순환로', '남부', '관악구', '서울시', '입구', '단계', '밑반찬', '중화', '필수', '야장',
#        '도리', '노원역', '뭔가', '짜조', '프리미엄', '가능', '직관', '소고기', '숯불', '강남역',
#        '이외', '우소', '꿀팁', '일본여행', '징유', '주변', '경찰서', '부산진', '청춘', '달리',
#        '매달', '크게', '독도', '홈파티', '평일', '비빔', '스타일', '편이', '야외', '출구',
#        '전포역', '건물', '양장', '미림', '화랑', '고추장', '그것', '청양고추', '행사', '맥주',
#        '이벤트', '홍솜', '의사', '사장', '원곡동', '동치미', '조금', '신라면', '최고', '순위',
#        '버전', '바게트', '기존', '버터', '소금', '사이드', '제스', '솔직', '핫반', '후반', '입술',
#        '발라', '살로', '축하', '컵라면', '유튜버들', '야끼소바', '유튜버', '종종', '포점', '불스지',
#        '날씨', '안성맞춤', '혼술족', '한신포차', '스토', '느낌', '개수', '냉장', '줄줄', '납작',
#        '오리', '퀄리티', '맛깔', '노력', '혹시', '강변', '오시', '대명사', '양념감자', '롯데리아',
#        '콧물', '체크', '탄수화물', '족발', '찜닭', '불고기', '운지', '관광객', '번길', '선로',
#        '영통구', '수원시', '경기', '부심', '정신', '당면', '맛불콩', '면서', '지옥', '대박',
#        '매력', '비빔면', '잔치', '엄궁', '영혼', '관심', '나라', '현지', '선택', '요새', '문의',
#        '가맹', '헬로', '이번', '재료', '해결', '선사', '희소식', '전하', '불콩뼈', '선생', '아이',
#        '두번째', '마무리', '뻘뻘', '안녕', '몸살', '꾸욱', '하니', '데친', '깻잎', '가위', '번의',
#        '줄기', '우선', '배추', '국내', '종류', '삼겹살', '공기', '굿굿', '쌀밥', '사이즈', '노원',
#        '설명', '셀프', '리필', '꼬들하', '코스', '가기', '음료', '끼리', '어른', '대감', '왕뽈찜',
#        '작전동', '뼈찜', '묵은지', '도장', '댓글', '공감', '메뉴판', '회식', '부평역', '인위',
#        '잔뜩', '호기심', '직접', '음료수', '여름', '남자', '제시', '나들이', '찰떡', '링크'],
#       dtype=object)

# %%
import requests
from bs4 import BeautifulSoup
from konlpy.tag import Okt
from collections import Counter
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from concurrent.futures import ThreadPoolExecutor
import time

# 네이버 API 인증 정보
client_id = 'JUIsxNlObCc7b3BCqWe1'
client_secret = 'pqVF4o6iit'

def get_blog_content(query, display):
    url = f"https://openapi.naver.com/v1/search/blog?query={query}&display={display}&sort=sim"
    headers = {
        "X-Naver-Client-Id": client_id,
        "X-Naver-Client-Secret": client_secret
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()['items']
    else:
        print("Error Code:", response.status_code)
        return None

def extract_food_names(text_list):
    okt = Okt()
    all_nouns = []

    for text in text_list:
        nouns = okt.nouns(text)
        all_nouns.extend(nouns)
    
    # 음식과 관련된 단어를 필터링합니다.
    food_names = [noun for noun in all_nouns if len(noun) > 1]
    
    return food_names

def fetch_and_extract_text(post):
    title = post['title']
    description = post['description']
    soup = BeautifulSoup(title + ' ' + description, 'html.parser')
    return soup.get_text()

def main():
    start_time = time.time()
    query = '매운 음식추천'
    blog_posts = get_blog_content(query, 100)
    
    if not blog_posts:
        return None
    
    with ThreadPoolExecutor() as executor:
        all_text = list(executor.map(fetch_and_extract_text, blog_posts))
    
    food_names = extract_food_names(all_text)
    
    food_counter = Counter(food_names)
    food_df = pd.DataFrame(food_counter.items(), columns=['Food', 'Count'])
    
    # 음식 메뉴 데이터
    menu_data = data['식품명'].tolist()

    # TF-IDF 벡터라이저를 사용하여 메뉴 데이터를 벡터화
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(menu_data)

    # 블로그 텍스트에서 명사 추출
    blog_text = " ".join(food_names)
    blog_tfidf = vectorizer.transform([blog_text])

    # CPU 코어 수에 맞게 병렬 처리
    with ThreadPoolExecutor() as executor:
        cosine_similarities = list(executor.map(lambda i: cosine_similarity(blog_tfidf, tfidf_matrix[i:i+1]).flatten()[0], range(len(menu_data))))

    # 유사도가 높은 명사 필터링 (임계값 설정, 여기서는 0.3로 설정)
    threshold = 0.1
    similar_nouns = [menu_data[i] for i in range(len(cosine_similarities)) if cosine_similarities[i] > threshold]

    # 유사한 명사들만 포함하는 데이터프레임 생성
    similar_food_df = food_df[food_df['Food'].isin(similar_nouns)]

    print("유사한 명사들로 구성된 데이터프레임:")
    print(similar_food_df)

    print(f"Execution time: {time.time() - start_time} seconds")
    return similar_food_df

if __name__ == "__main__":
    similar_food_df = main()
    if similar_food_df is not None:
        print(similar_food_df)
# Out:
# 유사한 명사들로 구성된 데이터프레임:
#     Food  Count
# 224  쌀국수      5
# 238   김밥      7
# 288   국밥     21
# 310   라면      5
# 335  감자탕     10
# 355  떡볶이      5
# Execution time: 62.795382022857666 seconds
#     Food  Count
# 224  쌀국수      5
# 238   김밥      7
# 288   국밥     21
# 310   라면      5
# 335  감자탕     10
# 355  떡볶이      5

# %% [markdown]
# ### 메뉴 추천이면 뽑아놓은 메뉴 데이터의 이름들을 빈도수로 계산해서 가져오면 될것같다.
# - 어차피 추천하지 못할 메뉴들은 카운트를 해봤자 추천을 못하니 우리가 수집해놓은 메뉴 데이터의 이름들만 해도 괜찮을 것같다.

# %%
import pandas as pd
from io import StringIO

file_path = 'data/TB_RECIPE_SEARCH-20231130.csv'

# 파일을 바이너리 모드로 읽고, 디코딩 오류를 무시하면서 문자열로 변환
with open(file_path, 'rb') as file:
    raw_data = file.read()
    decoded_data = raw_data.decode('euc-kr', errors='ignore')

# 변환된 문자열을 StringIO 객체로 만들어 pandas로 읽기
data = StringIO(decoded_data)
df = pd.read_csv(data)
# Out:
#    RCP_SNO          RCP_TTL CKG_NM   RGTR_ID RGTR_NM  INQ_CNT  RCMM_CNT  \
# 0   128671            어묵김말이  어묵김말이  skfo0701      꽃날    10072         6
# 1   128892  두부에 꼬리가 달렸어요!!   두부새우전  skfo0701      꽃날     5817         3
# 2   128932        입안에서 톡톡톡      알밥  skfo0701      꽃날     6975         8
# 3   131871           ★현미호두죽  현미호두죽   cds1117   햇님&별님     3339         0
# 4   139247  부들부들 보들보들 북어갈비♥   북어갈비  skfo0701      꽃날     7173         3
#
#    SRAP_CNT CKG_MTH_ACTO_NM CKG_STA_ACTO_NM CKG_MTRL_ACTO_NM CKG_KND_ACTO_NM  \
# 0        66              튀김              간식            가공식품류             디저트
# 1        27              부침              일상              해물류             밑반찬
# 2        36              굽기              일상              해물류           밥/죽/떡
# 3        11             끓이기              일상                쌀           밥/죽/떡
# 4        97              굽기             술안주             건어물류            메인반찬
#
#                                             CKG_IPDC  \
# 0                         맛있는 김말이에 쫄깃함을 더한 어묵 김말이예요-
# 1  꼬리가 너-무- 매력적인 두부새우전. 두부와 야채를 한번에!! 영양까지 만점인 두부...
# 2  간단하게 만들어 보는 알이 톡톡톡 알밥♥ 다 먹고 누룽지까지 싹싹 긁어먹는게 최고죠...
# 3                                              현미호두죽
# 4  오늘은 집에서 굴러다니고 쉽게 구할 수 있는 북어로 일품요리를 만들어 보았어요! 도...
#
#                                          CKG_MTRL_CN CKG_INBUN_NM CKG_DODF_NM  \
# 0  [재료] 어묵 2개| 김밥용김 3장| 당면 1움큼| 양파 1/2개| 당근 1/2개|...          2인분          초급
# 1  [재료] 두부 1/2모| 당근 1/2개| 고추 2개| 브로콜리 1/4개| 새우 4마...          3인분          초급
# 2  [재료] 밥 1+1/2공기| 당근 1/4개| 치자단무지 1/2개| 신김치 1쪽| 무...          2인분          초급
# 3           [재료] 현미 4컵| 찹쌀 2컵| 호두 50g| 물 1/2컵| 소금 약간          2인분          초급
# 4  [재료] 북어포 1마리| 찹쌀가루 1C [양념] 간장 2T| 설탕 1T| 물 1T|...          2인분          초급
#
#   CKG_TIME_NM    FIRST_REG_DT
# 0       60분이내  20070402131403
# 1       30분이내  20070402205937
# 2       30분이내  20070402224355
# 3       30분이내  20070410142301
# 4       60분이내  20070501000844

# %%
len(df)
# Out:
# 184991

# %%
df.iloc[[4]]
# Out:
#    RCP_SNO          RCP_TTL CKG_NM   RGTR_ID RGTR_NM  INQ_CNT  RCMM_CNT  \
# 4   139247  부들부들 보들보들 북어갈비♥   북어갈비  skfo0701      꽃날     7173         3
#
#    SRAP_CNT CKG_MTH_ACTO_NM CKG_STA_ACTO_NM CKG_MTRL_ACTO_NM CKG_KND_ACTO_NM  \
# 4        97              굽기             술안주             건어물류            메인반찬
#
#                                             CKG_IPDC  \
# 4  오늘은 집에서 굴러다니고 쉽게 구할 수 있는 북어로 일품요리를 만들어 보았어요! 도...
#
#                                          CKG_MTRL_CN CKG_INBUN_NM CKG_DODF_NM  \
# 4  [재료] 북어포 1마리| 찹쌀가루 1C [양념] 간장 2T| 설탕 1T| 물 1T|...          2인분          초급
#
#   CKG_TIME_NM    FIRST_REG_DT
# 4       60분이내  20070501000844

# %% [markdown]
# ### 이런 식으로 우리가 리스트업한 메뉴들을 검색해서 뽑아 사용하는 정도로 사용해야할 것 같다.

# %%
df[df['CKG_NM'] == '삼겹살']
# Out:
#         RCP_SNO                                         RCP_TTL CKG_NM  \
# 1631     997255                            양파와 함께 먹는 그릴에 구운 삼겹살    삼겹살
# 15590   4623918                                  두말 필요없는 양념 삼겹살    삼겹살
# 26547   6828963                         삼겹살 맛있게 먹는법  홈파티 음식 레시피    삼겹살
# 29167   6832118                              와인삼겹살 초간단레시피로 근사하게    삼겹살
# 30422   6833469                                      한입 쏙~~삼겹살     삼겹살
# 34544   6838357                          언제먹어도 맛있는 삼겹살 더욱 건강하게!    삼겹살
# 37644   6842577                                 된장삼겹살과 허브삼겹살만들기    삼겹살
# 39149   6844558                                바다오징어 & 육지삼겹살 만남    삼겹살
# 40423   6846251                                   돼지고기 잡내꺼져 통삼겹    삼겹살
# 58246   6871045                             치즈크림소스를 곁들인 삼겹살야채그릴    삼겹살
# 58297   6871110                                     돈(豚)을 품은 달     삼겹살
# 65810   6880862                              에어프라이어사용 : 통삼겹요리하기    삼겹살
# 68994   6884758                                 기름기 쫙~~ 뺀 벌집삼겹살    삼겹살
# 69382   6885222                   삼겹살소스 고기의 느끼함을 잡아주는 새콤상콤한 소스~    삼겹살
# 72327   6888843                           삼겹살 요리  저크시즈닝 로스트 삼겹살    삼겹살
# 75002   6892183                              바삭 벌집삼겹살& 새콤달콤 파무침    삼겹살
# 75366   6892636                        에어프라이로 벌집삼겹살 기름 쪽빼고 구워먹기    삼겹살
# 78665   6896510               (에어프라이어 요리) 에어프라이어 삼겹살 - 온도와 조리시간    삼겹살
# 83608   6902213  삼겹살 요리 고추장마늘&된장마늘 삼겹살 구워 먹었어요 :) (feat. 부추무침)     삼겹살
# 83814   6902477     에어프라이어 삼겹살 :)소금 후추 만으로 최고에요 ^^크리스마스에 어울리는 ♡    삼겹살
# 87669   6906891             가스렌지 기름 튀기는 거 시러~ 오븐에 구운 레몬향 가득 삼겹살    삼겹살
# 89190   6908770                        담백하게 즐기는 에어프라이어 삼겹살 굽기 팁    삼겹살
# 92275   6912381                             삼겹살 젓갈에 찍어 맛있게 먹기~*    삼겹살
# 96365   6917111                         에어프라이어표 칼집삼겹살 & 양파초절임 ★    삼겹살
# 98661   6919737                     에어프라이어 삼겹살 촉촉하게 즐기는 통삼겹 레시피    삼겹살
# 102875  6924465                               에어프라이어 삼겹살 촉촉한 시간    삼겹살
# 106115  6928077                                        구이구이 삼겹살    삼겹살
# 111575  6934193                       에어프라이어 삼겹살 굽기 & 앞다리살 간장구이    삼겹살
# 133473  6958307                              삼겹살 찰떡궁합 상추겉절이 만들기    삼겹살
# 146902  6973108                                       에어프라이어삼겹살    삼겹살
# 173528  7002748                                    삼겹살 맛있게 굽는 법    삼겹살
#
#             RGTR_ID         RGTR_NM  INQ_CNT  RCMM_CNT  SRAP_CNT  \
# 1631      yummycook             윤희정     6982        13        48
# 15590         kdlym               윤    49659        12      1200
# 26547      77955879      DanielSong    21391         4       168
# 29167     ccamgic75            핑크쥬디    59752        56      1766
# 30422     00black70        도시락만드는아빠     2254         2        48
# 34544      77955879      DanielSong     3575         2        45
# 37644      kstencil            강철새잎     5824         4        80
# 39149      75155461             초이맘     5265         4       176
# 40423   jungmin2005          카리스마정민     3357         1        23
# 58246       ksg3152        쉐프cookie     2166         3        55
# 58297      52346103          포레스트키친     2623         3        59
# 65810      73309114           빼꼼쪼미맘    25134         0       226
# 68994      49723494      양고은(채린♥은찬)     4061         0        13
# 69382      kyss7700          요리쿡조리쿡     6464         0        85
# 72327      77955879          메이플대니얼     9849         1        76
# 75002      89234500            재미마미     4234         0        45
# 75366    gidtnstltl            다다도맘    16265         0        89
# 78665      41762813            아랄랄라   487857         0      1414
# 83608    sseunghyee         승혜의야미로그     3220         0        29
# 83814      28445004            울탱이?    23287         0       192
# 87669      33006056  EasyFusion집밥er     5300         0        89
# 89190      77955879          메이플대니얼    29217         0       179
# 92275      62299079            밥차리라     5876         0        62
# 96365       gdubu33          만개의레시피    17962         0       542
# 98661      77955879          메이플대니얼    11620         0       226
# 102875    hyuna9595              먹순     4182         0        37
# 106115     72803080           도유니유니     2701         0        38
# 111575      redlily            피에스타     2662         0        26
# 133473     79115518            구름달빛     1425         0        33
# 146902     89234500            재미마미     1084         0         6
# 173528     dpwl7953            쿠킹천국     2152         0         4
#
#        CKG_MTH_ACTO_NM CKG_STA_ACTO_NM CKG_MTRL_ACTO_NM CKG_KND_ACTO_NM  \
# 1631                굽기              일상             돼지고기            메인반찬
# 15590               굽기              일상             돼지고기            메인반찬
# 26547               굽기            손님접대             돼지고기            메인반찬
# 29167               굽기            손님접대             돼지고기            메인반찬
# 30422               굽기              일상             돼지고기            메인반찬
# 34544               굽기              일상             돼지고기            메인반찬
# 37644               굽기              일상             돼지고기            메인반찬
# 39149              끓이기              일상             돼지고기              찌개
# 40423              끓이기              일상             돼지고기            메인반찬
# 58246               굽기              일상             돼지고기            메인반찬
# 58297               굽기              일상             돼지고기            메인반찬
# 65810               굽기            손님접대             돼지고기            메인반찬
# 68994               굽기            손님접대             돼지고기            메인반찬
# 69382               기타              일상             돼지고기         양념/소스/잼
# 72327               굽기              일상             돼지고기            메인반찬
# 75002               굽기              일상             돼지고기            메인반찬
# 75366               굽기              일상             돼지고기            메인반찬
# 78665               굽기             술안주             돼지고기            메인반찬
# 83608               굽기              일상             돼지고기            메인반찬
# 83814               굽기              일상             돼지고기            메인반찬
# 87669               굽기              일상             돼지고기            메인반찬
# 89190               굽기              일상             돼지고기            메인반찬
# 92275              끓이기            초스피드             돼지고기            메인반찬
# 96365               굽기              일상             돼지고기            메인반찬
# 98661               굽기              일상             돼지고기            메인반찬
# 102875              굽기              일상             돼지고기            메인반찬
# 106115              굽기              일상             돼지고기            메인반찬
# 111575              굽기            손님접대             돼지고기            메인반찬
# 133473              무침              일상              채소류             밑반찬
# 146902              굽기              일상             돼지고기            메인반찬
# 173528              굽기              일상             돼지고기            메인반찬
#
#                                                  CKG_IPDC  \
# 1631    삽겹살을 양념을 해서 가스레인지 그릴에 알맞게 구워 보았어요. 곁들이로는 간단하게 ...
# 15590   한동안 아니 지금까지도 인기메뉴 중의 하나인 대패 삼겹살을 아시나요? 저도 한번 맛...
# 26547   껍데기가 붙어있는 삼겹살 부위(소위 오겹살)를 사용해서 통삼겹 오븐 구이를 만들어 ...
# 29167                     평범한 보쌈은가라!! 와인과 간장소스로 근사하게변신~^^
# 30422   구운 삼겹살을 샐러드 야채와 함께 곁들여 먹어요  간편하게 드시고 싶은 요리이구요 ...
# 34544   이번 포스팅에서는 전국민이 사랑하는 돼지고기 부위인 삼겹살 맛있게 먹는법  레시피로...
# 37644                         된장양념과 허브양념으로 색다르게 즐기는 삼겹살구이
# 39149   오징어도 먹고 싶고 삼겹살도 먹고 싶고 역시 고추장 듬뿍 넣은 오삼불고기 아니겠어요...
# 40423   고기를 쌈싸먹는걸 안좋아해요.보통 고기육즙을 느끼려고 그냥 채소와 따로 먹기때문 해...
# 58246   그릴에 고기와 야채를 함께 구워서 짭쪼롬한 크림소스를 곁들여 재료도 간단하고 조리도...
# 58297   저희는 친구들이랑 캠핑 자주가는데요 캠핑장 가면 삼겹살 많이 구워먹자나요 근데 삼겹...
# 65810   에어프라이어가 있다면 통삼겹요리를 빼먹을 수 없죠? 기름이 쏙 빠진 에어프라이어표 ...
# 68994   특별한 주말 저녁식사에 삼겹살....하지만 온 집안에 풍기는 냄새와 기름기와 지방덩...
# 69382   기름기 많은 삼겹살은 왠만하면 집에서는 잘 안구워 먹게 되는데요  아들이 원츄해서 ...
# 72327   톡 쏘는 매콤한 향 뒤에 은은하게 올라오는 스모키한 풍미.이곳 캐나다 토론토의 자메...
# 75002   삼겹살 더 바삭하게 구우려면? 고기를 더 맛있게 먹는 파무침(파절이)는? 삼겹살브런...
# 75366   요즘 삼겹살의 가격이 고공행진하네요.  이럴때일수록 더 먹고싶어지는 삼겹살 ㅋ  여...
# 78665   에어프라이어를 산 가장 큰 이유가  삼겹살을 편하고 맛있게 구워 먹기 위해서였습니다...
# 83608   한 번에 두 가지 맛을 먹어볼 수 있는 고추장마늘&된장마늘 삼겹살을  만들어볼게요!...
# 83814   미세먼지에 좋은 삼겹살입니다^-^ 에어프라이어로 소금 후추만 있으면 간단히 금방 완...
# 87669   코스코 삼겹살 신선하고 맛있지만 너무 두껍게 썰어놔서 팬에서 구우려면 오래걸리고 기...
# 89190   출시 초창기에는 활용성에 대한 의구심과 함께 쉽게 구입하여 사용하기에는 다소 가격대...
# 92275   울 집 꼬기 구워 먹을땐 요 젓갈 양념은  빠지지 않네유 캠핑을 가도 꼬옥~ 챙겨 ...
# 96365   에어프라이어로 구워진 삼겹살이란 ?  소름돋게 맛있구먼 ~! 양파 초절임은 보너스란...
# 98661   에어프라이어 인기 레시피를 한 가지 꼽으라면 단연 통 삼겹살 구이를 제쳐 놓고 생각...
# 102875  에어프라이어를 활용한 삼겹살  얇은 고기도 촉촉하게 맛있게 익힐 수 있는 시간 소개...
# 106115  33데이를 맞아 색다른 삼겹살 요리를 해보려고 해요. 삼겹살과 채소만 준비하면 된답니다~
# 111575  주말 잘 보내셨어요? 정말 너무 더웠죠. 미세먼지도 좋지 않아서 에어컨 틀고서 아이...
# 133473  상추겉절이는 지금 먹어야 딱 맛있는 거 같아요 봄이 오면 상추가 텃밭에서 모습을 드...
# 146902                                에어프라이어에 삼겹살과 마늘쫑 굽기
# 173528  언제나 먹어도 맛있는 돼지고기 삼겹살이다. 기름이 많지만 매력적인 맛을 끊을 수 없...
#
#                                               CKG_MTRL_CN CKG_INBUN_NM  \
# 1631    [재료] 삽겹살| 양파| 김치 [고기밑간] 허브맛솔트 약간| 허브맛솔트(마늘) 약간...          3인분
# 15590   [재료] 삼겹살 2근| 청양고추 6개| 대파 2대 [양념] 사과 1/4쪽| 배 1/...          2인분
# 26547   [재료] 삼겹살 250g| 마늘 130g| 로즈마리 40g| 라임 1/4개 [카레 ...          2인분
# 29167   [재료] 돼지고기 600g| 깻잎 10장| 양파 1개 [양념] 간장 1/2종이컵| ...          4인분
# 30422   [재료] 삼겹살 200| 샐러드 야채 1줌| 방울토마토 2~4개 [양념] 발사믹식초...          2인분
# 34544                [재료] 자세한 재료는 본문내용에서| 확인 해 보실 수 있습니다.          1인분
# 37644   [된장삼겹살양념] 된장| 다진마늘| 다진파| 꿀| 월계수잎 [허브삼겹살양념] 바질가...          2인분
# 39149   [재료] 삼겹살 600g| 오징어 1마리(230g) [양념] 고추장 2스푼| 양파 ...          4인분
# 40423   [재료] 돼지고기 500g| 양파 1개| 생강 4쪽| 월계수잎(생략가능) 5장| 미...          2인분
# 58246   [재료] 돼지 삼겹살 400g | 가지 1개| 새송이버섯 1개 | 통마늘 8개| 양...          3인분
# 58297   [메인재료] 돼지고기 삼겹살 500g| 또띠아 6장| 칵테일새우(크기는 취향대로) ...          2인분
# 65810                             [재료] 돼지고기| 통후추| 통마늘| 소금          2인분
# 68994   [재료] 벌집삼겹살 1근| 양파 2개| 버섯 2개 [양념] 쌈장 2스푼| 상추 1봉...          4인분
# 69382   [재료] 삼겹살| 허브솔트| 페퍼시즈닝(or후추) [소스재료] 사과 1/2개| 양파...          2인분
# 72327   [재료] 삼겹살 250g| 양파 1개| 할라피뇨고추 2개| 월계수잎 4장 [샐러드재...          1인분
# 75002   [재료] 벌집삼겹살 500그램| 식용유 1~2큰술| 깻잎| 포기생채(상추) [파무침...          2인분
# 75366                 [재료] 벌집 삼겹살 600g| 허브솔트 약간| 새송이버섯 3개          4인분
# 78665   [주재료] 삼겹살 500g| 허브솔트(또는맛소금) [선택 재료] 통마늘| 올리브유 ...          2인분
# 83608   [재료] 칼집 낸 삼겹살 1/2근| 고추장 1스푼| 된장 1스푼| 다진 마늘 3스푼...          1인분
# 83814            [재료] 돼지고기 1/2~1근| 양파 1개| 쌈채소 [양념] 소금| 후추          2인분
# 87669   [재료] 삼겹살 1Kg| 레몬(대) 2개| 통마늘 30알| 소금 약간| 후추 약간|...          4인분
# 89190           [재료] 삼겹살 200g| 목살 200g| 허브소금 1T| 올리브오일 1T          1인분
# 92275                  [재료] 멸치 젓 3큰술| 땡초 3| 통마늘 7| 소주 5큰술          3인분
# 96365   [필수재료] 삼겹살 600g| 양파 1개 [양념재료] 간장 5숟가락| 식초 5숟가락...          3인분
# 98661   [재료] 통삼겹살 300g| 마늘 100g| 파슬리 1/2t [ 통삼겹살 시즈닝 재...          1인분
# 102875                    [재료] 삼겹살 250g| 소금 1작은술| 후추 1작은술          2인분
# 106115         [재료] 삼겹살 200g| 양파 1/4개| 고추 1개 [양념] 굴소스 적당히          1인분
# 111575  [재료] 돼지고기앞다리살 300g| 맛술 1T| 후추 약간 | 진간장 1T| 올리고...          2인분
# 133473  [재료] 상추| 양파| 고춧가루 1큰술| 간장 1큰술| 식초 1큰술| 설탕 1/2큰...          4인분
# 146902          [재료] 삼겹살 500g| 마늘쫑 10줄 | 소주 1컵| 그라인드후추 약간          2인분
# 173528  [재료] 삼겹살 1.5kg| 소금 약간| 후추 약간| 파프리카 가루 약간| 마늘 가...          4인분
#
#        CKG_DODF_NM CKG_TIME_NM    FIRST_REG_DT
# 1631           아무나       30분이내  20090109065534
# 15590           중급       2시간이상  20130305073918
# 26547           초급       60분이내  20150615061626
# 29167           초급       30분이내  20150817134342
# 30422          아무나       15분이내  20150903190410
# 34544          아무나       30분이내  20151119132716
# 37644          아무나       60분이내  20160204092441
# 39149           초급       30분이내  20160312121131
# 40423           초급       30분이내  20160411085714
# 58246           초급       30분이내  20170611141841
# 58297           초급       30분이내  20170612225823
# 65810          아무나       30분이내  20171212151808
# 68994           초급       60분이내  20180301230528
# 69382           초급       15분이내  20180310085256
# 72327           초급       60분이내  20180515002942
# 75002           초급       30분이내  20180708224946
# 75366          아무나       30분이내  20180716150536
# 78665          아무나       60분이내  20180925160613
# 83608           초급       60분이내  20181217150256
# 83814           초급       30분이내  20181220201145
# 87669          아무나       60분이내  20190219095059
# 89190          아무나       30분이내  20190320024915
# 92275          아무나        5분이내  20190518233105
# 96365           초급       60분이내  20190807180007
# 98661           초급       90분이내  20190927073351
# 102875         아무나         NaN  20200103230028
# 106115         아무나       30분이내  20200309162431
# 111575         아무나       60분이내  20200611164447
# 133473         아무나       15분이내  20210513152221
# 146902         아무나         NaN  20220119224613
# 173528         아무나       15분이내  20230523203200

# %%
df['CKG_NM'].nunique()
# Out:
# 49677

# %%
df.columns
# Out:
# Index(['RCP_SNO', 'RCP_TTL', 'CKG_NM', 'RGTR_ID', 'RGTR_NM', 'INQ_CNT',
#        'RCMM_CNT', 'SRAP_CNT', 'CKG_MTH_ACTO_NM', 'CKG_STA_ACTO_NM',
#        'CKG_MTRL_ACTO_NM', 'CKG_KND_ACTO_NM', 'CKG_IPDC', 'CKG_MTRL_CN',
#        'CKG_INBUN_NM', 'CKG_DODF_NM', 'CKG_TIME_NM', 'FIRST_REG_DT'],
#       dtype='object')
