# %% [markdown]
# ### JSON 데이터 전처리 후 JSON파일을 데이터프레임으로 변경
# - 임의로 0으로 설정하긴 했는데 이건 상의 후 결정
# - 0으로 하면 등급이 0 등급도 있고 측정값이 0인 것도 있어서 영향을 줄 것 같다.
# - 어떻게 해야할까?

# %%
# JSON파일을 DataFrame으로 변경
# 데이터 프레임에 값이 딕셔너리를 문자열로 만들어 값에 들어가 있어 문자열 -> 딕셔너리
import os
import json
import pandas as pd
from ultralytics import YOLO
def create_labeling_dataframe(base_path):
    data = []
    for split in ['Validation', 'Training']:
        label_path = os.path.join(base_path, split, '02.라벨링데이터')
        if not os.path.exists(label_path):
            print(f"경로가 존재하지 않습니다: {label_path}")
            continue
        for file in os.listdir(label_path):
            if file.endswith('.json'):
                with open(os.path.join(label_path, file), 'r') as f:
                    json_data = json.load(f)
                    row = {
                        'split': split,
                        'info': json.dumps(json_data.get('info', {})),
                        'images': json.dumps(json_data.get('images', {})),
                        'annotations': json.dumps(json_data.get('annotations', {})),
                        'equipment': json.dumps(json_data.get('equipment', {}))
                    }
                    data.append(row)
    
    df = pd.DataFrame(data)
    
    # JSON 문자열을 딕셔너리로 변환
    for col in ['info', 'images', 'annotations', 'equipment']:
        df[col] = df[col].apply(lambda x: x if isinstance(x, dict) else json.loads(x) if isinstance(x, str) else x)
    
    return df
  
base_path = 'data'
df = create_labeling_dataframe(base_path)

df.head(3)

# %%
# 5. 데이터 프레임 전처리

# 데이터 프레임 None 값을 {}로 변경
# 딕셔너리 안에 None 값을 0으로 바꾸는 함수 정의
# acne -> 0이 없는 거
def replace_none_with_zero(d):
    if isinstance(d, dict):
        return {k: (0 if v is None else v) for k, v in d.items()}
    return d

# 데이터 프레임의 모든 셀에 대해 함수 적용
df = df.applymap(replace_none_with_zero)

# 'equipment' 컬럼에 null 값을 빈 딕셔너리로 변경
df['equipment'] = df['equipment'].apply(lambda x: {} if pd.isna(x) else x)
df.head(3)

# %%
len(df)

# %%
df.iloc[0]['info']

# %%
df.to_csv('data.csv', index=False)

# %% [markdown]
# ### YOLOv8을 사용한 얼굴 부위 분류 모델 학습

# %%
import os
import json
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from ultralytics import YOLO
from PIL import Image
import shutil
import ast
import matplotlib.pyplot as plt

# %%
# YAML 파일 생성 함수
def create_yolo_yaml(base_path):
    yaml_content = f"""
path: {base_path}
train: Training/images
val: Validation/images
nc: 9
names: ['forehead', 'glabella', 'left_eye', 'right_eye', 'left_cheek', 'right_cheek', 'nose', 'mouth', 'chin']

train_labels: Training/labels
val_labels: Validation/labels
"""
    yaml_path = os.path.join(base_path, 'dataset.yaml')
    with open(yaml_path, 'w', encoding='utf-8') as f:
        f.write(yaml_content)
    return yaml_path

# %%
# 손상된 이미지와 라벨링 같이 제거
def remove_corrupted_images(folder_path):
    corrupted_images = []
    for filename in os.listdir(folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            file_path = os.path.join(folder_path, filename)
            try:
                with Image.open(file_path) as img:
                    img.verify()
            except Exception as e:
                print(f"손상된 이미지 파일 발견: {filename}")
                corrupted_images.append(filename)
                os.remove(file_path)
    return corrupted_images

# %%
# yolo형식으로 데이터 전처리 함수
def prepare_yolo_data(df, base_path):
    train_image_path = os.path.join(base_path, 'Training', 'images')
    val_image_path = os.path.join(base_path, 'Validation', 'images')
    train_label_path = os.path.join(base_path, 'Training', 'labels')
    val_label_path = os.path.join(base_path, 'Validation', 'labels')

    # 모든 필요한 폴더가 이미 존재하는지 확인
    if all(os.path.exists(path) for path in [train_image_path, val_image_path, train_label_path, val_label_path]):
        print("기존 데이터 폴더를 사용합니다.")
        return train_image_path, val_image_path, train_label_path, val_label_path

    # 폴더가 없는 경우 새로 생성
    os.makedirs(train_image_path, exist_ok=True)
    os.makedirs(val_image_path, exist_ok=True)
    os.makedirs(train_label_path, exist_ok=True)
    os.makedirs(val_label_path, exist_ok=True)

    print("Training 데이터에서 손상된 이미지 제거 중...")
    remove_corrupted_images(train_image_path)
    print("Validation 데이터에서 손상된 이미지 제거 중...")
    remove_corrupted_images(val_image_path)

    processed_count = 0
    for index, row in df.iterrows():
        try:
            info = row['info']
            images = row['images']

            filename = info['filename']
            facepart = images['facepart']
            bbox = images['bbox']
            width = images['width']
            height = images['height']

            src_img_path = os.path.join(base_path, row['split'], '01.원천데이터', filename)
            dst_img_path = os.path.join(train_image_path if 'Training' in row['split'] else val_image_path, filename)

            if not os.path.exists(src_img_path):
                print(f"{index}번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: {filename}")
                continue

            # 이미지 파일 복사
            shutil.copy2(src_img_path, dst_img_path)

            if not all([filename, facepart is not None, width, height, bbox]):
                print(f"{index}번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: {filename}")
                continue

            if (bbox == ['None', 'None', 'None', 'None']) or not all(isinstance(b, (int, float)) and b is not None for b in bbox):
                print(f"{index}번 행을 건너뜁니다. 유효하지 않은 bbox 값입니다. 파일: {filename}")
                continue

            bbox = [float(b) for b in bbox]
            width = float(width)
            height = float(height)

            x_center = (bbox[0] + bbox[2]) / 2 / width
            y_center = (bbox[1] + bbox[3]) / 2 / height
            bbox_width = (bbox[2] - bbox[0]) / width
            bbox_height = (bbox[3] - bbox[1]) / height

            yolo_format = f"{facepart} {x_center} {y_center} {bbox_width} {bbox_height}\n"

            label_path = train_label_path if 'Training' in row['split'] else val_label_path
            label_filename = os.path.splitext(filename)[0] + '.txt'

            with open(os.path.join(label_path, label_filename), 'a') as f:
                f.write(yolo_format)

            processed_count += 1

        except Exception as e:
            print(f"{index}번 행 처리 중 오류 발생: {str(e)}")
            print(f"행 데이터: {row}")

    print(f"총 {processed_count}개의 이미지를 처리했습니다.")
    return train_image_path, val_image_path, train_label_path, val_label_path

# %%
# 성능 시각화 함수
import matplotlib.pyplot as plt

def plot_performance(results):
    metrics = ['box_loss', 'cls_loss', 'dfl_loss', 'mAP50', 'mAP50-95', 'precision', 'recall']

    fig, axs = plt.subplots(3, 3, figsize=(20, 20))
    axs = axs.ravel()  # 2D array를 1D array로 변환

    for i, metric in enumerate(metrics):
        ax = axs[i]
        if metric in results.results_dict:
            ax.plot(results.results_dict[metric], label=f'train_{metric}')
            if f'val_{metric}' in results.results_dict:
                ax.plot(results.results_dict[f'val_{metric}'], label=f'val_{metric}')
            ax.set_title(f'{metric.replace("_", " ").capitalize()}')
            ax.set_xlabel('Epoch')
            ax.set_ylabel('Value')
            ax.legend()

    # 사용하지 않는 서브플롯 제거
    for j in range(i+1, 9):
        fig.delaxes(axs[j])

    plt.tight_layout()
    plt.savefig('training_performance.png')
    plt.close()

    print("성능 그래프가 'training_performance.png'로 저장되었습니다.")

# %%
# YOLO 모델 학습
def train_yolo_model(df, base_path):
    train_image_path, val_image_path, train_label_path, val_label_path = prepare_yolo_data(df, base_path)

    yaml_path = create_yolo_yaml(base_path)

    model = YOLO('yolov8n.yaml')
    results = model.train(data=yaml_path, epochs=30, imgsz=640)

    model.save('yolov8_facepart_model.pt')

    plot_performance(results)

    return model, results

# %%
# 함수들 실행
if __name__ == "__main__":
    base_path = os.path.abspath('data')
    
    df = pd.read_csv(base_path + '/json to df.csv')
    
    # csv로 불러오니 딕셔너리가 문자열로 다 바뀌어서 나와 딕셔너리로 변환
    for col in ['info', 'images', 'annotations', 'equipment']:
        df[col] = df[col].apply(lambda x: ast.literal_eval(x) if x else None)
        
    trained_model, training_results = train_yolo_model(df, base_path)
    
    if trained_model:
        print("모델 학습이 완료되었습니다.")
        print("학습 결과:", training_results)
        print("학습된 모델이 'yolov8_facepart_model.pt'로 저장되었습니다.")
    else:
        print("모델 학습에 실패했습니다.")
# Out:
# Training 데이터에서 손상된 이미지 제거 중...
# Validation 데이터에서 손상된 이미지 제거 중...
# 58번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0001_01_R30.jpg
# 75번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0001_02_L.jpg
# 85번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0001_02_R.jpg
# 102번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0001_03_L.jpg
# 112번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0001_03_R.jpg
# 175번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_01_R30.jpg
# 192번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_02_L.jpg
# 202번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_02_R.jpg
# 210번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_03_F.jpg
# 211번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_03_F.jpg
# 214번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_03_F.jpg
# 217번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_03_L.jpg
# 219번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_03_L.jpg
# 221번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_03_L.jpg
# 223번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_03_L.jpg
# 226번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_03_R.jpg
# 229번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_03_R.jpg
# 231번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0004_03_R.jpg
# 264번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0013_01_L15.jpg
# 273번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0013_01_L30.jpg
# 292번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0013_01_R30.jpg
# 309번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0013_02_L.jpg
# 319번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0013_02_R.jpg
# 336번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0013_03_L.jpg
# 346번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0013_03_R.jpg
# 409번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0021_01_R30.jpg
# 426번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0021_02_L.jpg
# 436번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0021_02_R.jpg
# 453번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0021_03_L.jpg
# 455번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0021_03_L.jpg
# 463번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0021_03_R.jpg
# 526번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0050_01_R30.jpg
# 543번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0050_02_L.jpg
# 553번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0050_02_R.jpg
# 570번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0050_03_L.jpg
# 572번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0050_03_L.jpg
# 580번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0050_03_R.jpg
# 660번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0061_02_L.jpg
# 670번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0061_02_R.jpg
# 678번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0061_03_F.jpg
# 679번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0061_03_F.jpg
# 687번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0061_03_L.jpg
# 689번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0061_03_L.jpg
# 697번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0061_03_R.jpg
# 699번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0061_03_R.jpg
# 760번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0072_01_R30.jpg
# 777번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0072_02_L.jpg
# 787번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0072_02_R.jpg
# 804번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0072_03_L.jpg
# 806번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0072_03_L.jpg
# 814번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0072_03_R.jpg
# 894번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0082_02_L.jpg
# 904번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0082_02_R.jpg
# 921번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0082_03_L.jpg
# 923번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0082_03_L.jpg
# 931번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0082_03_R.jpg
# 933번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0082_03_R.jpg
# 1011번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0090_02_L.jpg
# 1021번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0090_02_R.jpg
# 1038번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0090_03_L.jpg
# 1048번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0090_03_R.jpg
# 1111번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0111_01_R30.jpg
# 1128번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0111_02_L.jpg
# 1138번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0111_02_R.jpg
# 1155번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0111_03_L.jpg
# 1157번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0111_03_L.jpg
# 1165번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0111_03_R.jpg
# 1167번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0111_03_R.jpg
# 1228번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0115_01_R30.jpg
# 1245번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0115_02_L.jpg
# 1255번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0115_02_R.jpg
# 1272번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0115_03_L.jpg
# 1274번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0115_03_L.jpg
# 1282번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0115_03_R.jpg
# 1345번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0117_01_R30.jpg
# 1362번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0117_02_L.jpg
# 1372번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0117_02_R.jpg
# 1389번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0117_03_L.jpg
# 1399번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0117_03_R.jpg
# 1479번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0120_02_L.jpg
# 1489번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0120_02_R.jpg
# 1506번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0120_03_L.jpg
# 1508번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0120_03_L.jpg
# 1516번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0120_03_R.jpg
# 1579번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0144_01_R30.jpg
# 1596번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0144_02_L.jpg
# 1606번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0144_02_R.jpg
# 1623번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0144_03_L.jpg
# 1633번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0144_03_R.jpg
# 1715번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0149_02_L.jpg
# 1723번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0149_02_R.jpg
# 1740번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0149_03_L.jpg
# 1750번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0149_03_R.jpg
# 1830번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0159_02_L.jpg
# 1840번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0159_02_R.jpg
# 1857번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0159_03_L.jpg
# 1867번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0159_03_R.jpg
# 1869번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0159_03_R.jpg
# 1930번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0168_01_R30.jpg
# 1947번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0168_02_L.jpg
# 1957번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0168_02_R.jpg
# 1974번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0168_03_L.jpg
# 1976번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0168_03_L.jpg
# 1984번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0168_03_R.jpg
# 1986번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0168_03_R.jpg
# 2028번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0186_01_L30.jpg
# 2047번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0186_01_R30.jpg
# 2064번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0186_02_L.jpg
# 2074번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0186_02_R.jpg
# 2091번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0186_03_L.jpg
# 2101번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0186_03_R.jpg
# 2164번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0207_01_R30.jpg
# 2181번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0207_02_L.jpg
# 2191번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0207_02_R.jpg
# 2208번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0207_03_L.jpg
# 2218번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0207_03_R.jpg
# 2262번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0249_01_L30.jpg
# 2298번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0249_02_L.jpg
# 2308번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0249_02_R.jpg
# 2317번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0249_03_F.jpg
# 2325번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0249_03_L.jpg
# 2335번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0249_03_R.jpg
# 2379번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0250_01_L30.jpg
# 2415번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0250_02_L.jpg
# 2425번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0250_02_R.jpg
# 2442번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0250_03_L.jpg
# 2452번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0250_03_R.jpg
# 2496번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0257_01_L30.jpg
# 2515번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0257_01_R30.jpg
# 2532번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0257_02_L.jpg
# 2542번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0257_02_R.jpg
# 2559번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0257_03_L.jpg
# 2561번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0257_03_L.jpg
# 2569번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0257_03_R.jpg
# 2632번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0262_01_R30.jpg
# 2649번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0262_02_L.jpg
# 2659번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0262_02_R.jpg
# 2676번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0262_03_L.jpg
# 2686번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0262_03_R.jpg
# 2749번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0275_01_R30.jpg
# 2766번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0275_02_L.jpg
# 2776번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0275_02_R.jpg
# 2793번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0275_03_L.jpg
# 2803번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0275_03_R.jpg
# 2847번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0277_01_L30.jpg
# 2866번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0277_01_R30.jpg
# 2883번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0277_02_L.jpg
# 2893번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0277_02_R.jpg
# 2910번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0277_03_L.jpg
# 2920번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0277_03_R.jpg
# 2983번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0307_01_R30.jpg
# 3000번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0307_02_L.jpg
# 3010번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0307_02_R.jpg
# 3027번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0307_03_L.jpg
# 3029번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0307_03_L.jpg
# 3037번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0307_03_R.jpg
# 3100번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0312_01_R30.jpg
# 3117번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0312_02_L.jpg
# 3127번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0312_02_R.jpg
# 3144번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0312_03_L.jpg
# 3154번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0312_03_R.jpg
# 3234번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0321_02_L.jpg
# 3244번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0321_02_R.jpg
# 3261번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0321_03_L.jpg
# 3271번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0321_03_R.jpg
# 3315번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0338_01_L30.jpg
# 3351번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0338_02_L.jpg
# 3361번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0338_02_R.jpg
# 3378번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0338_03_L.jpg
# 3388번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0338_03_R.jpg
# 3468번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0356_02_L.jpg
# 3478번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0356_02_R.jpg
# 3495번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0356_03_L.jpg
# 3505번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0356_03_R.jpg
# 3549번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0378_01_L30.jpg
# 3585번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0378_02_L.jpg
# 3595번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0378_02_R.jpg
# 3612번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0378_03_L.jpg
# 3622번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0378_03_R.jpg
# 3702번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0379_02_L.jpg
# 3712번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0379_02_R.jpg
# 3721번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0379_03_F.jpg
# 3729번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0379_03_L.jpg
# 3739번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0379_03_R.jpg
# 3783번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0390_01_L30.jpg
# 3802번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0390_01_R30.jpg
# 3819번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0390_02_L.jpg
# 3829번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0390_02_R.jpg
# 3846번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0390_03_L.jpg
# 3856번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0390_03_R.jpg
# 3919번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0398_01_R30.jpg
# 3936번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0398_02_L.jpg
# 3946번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0398_02_R.jpg
# 3963번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0398_03_L.jpg
# 3973번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0398_03_R.jpg
# 4036번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0402_01_R30.jpg
# 4053번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0402_02_L.jpg
# 4063번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0402_02_R.jpg
# 4090번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0402_03_R.jpg
# 4170번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0415_02_L.jpg
# 4197번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0415_03_L.jpg
# 4207번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0415_03_R.jpg
# 4287번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0418_02_L.jpg
# 4297번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0418_02_R.jpg
# 4314번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0418_03_L.jpg
# 4324번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0418_03_R.jpg
# 4368번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0444_01_L30.jpg
# 4404번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0444_02_L.jpg
# 4414번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0444_02_R.jpg
# 4431번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0444_03_L.jpg
# 4441번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0444_03_R.jpg
# 4443번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0444_03_R.jpg
# 4485번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0450_01_L30.jpg
# 4504번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0450_01_R30.jpg
# 4521번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0450_02_L.jpg
# 4531번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0450_02_R.jpg
# 4548번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0450_03_L.jpg
# 4558번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0450_03_R.jpg
# 4602번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0458_01_L30.jpg
# 4638번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0458_02_L.jpg
# 4648번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0458_02_R.jpg
# 4665번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0458_03_L.jpg
# 4675번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0458_03_R.jpg
# 4755번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0484_02_L.jpg
# 4765번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0484_02_R.jpg
# 4782번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0484_03_L.jpg
# 4792번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0484_03_R.jpg
# 4836번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0494_01_L30.jpg
# 4872번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0494_02_L.jpg
# 4882번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0494_02_R.jpg
# 4899번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0494_03_L.jpg
# 4909번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0494_03_R.jpg
# 4953번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0514_01_L30.jpg
# 4989번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0514_02_L.jpg
# 4999번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0514_02_R.jpg
# 5016번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0514_03_L.jpg
# 5026번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0514_03_R.jpg
# 5106번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0517_02_L.jpg
# 5116번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0517_02_R.jpg
# 5133번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0517_03_L.jpg
# 5143번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0517_03_R.jpg
# 5187번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0522_01_L30.jpg
# 5223번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0522_02_L.jpg
# 5233번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0522_02_R.jpg
# 5250번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0522_03_L.jpg
# 5260번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0522_03_R.jpg
# 5304번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0528_01_L30.jpg
# 5323번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0528_01_R30.jpg
# 5340번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0528_02_L.jpg
# 5350번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0528_02_R.jpg
# 5367번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0528_03_L.jpg
# 5377번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0528_03_R.jpg
# 5421번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0529_01_L30.jpg
# 5440번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0529_01_R30.jpg
# 5457번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0529_02_L.jpg
# 5467번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0529_02_R.jpg
# 5469번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0529_02_R.jpg
# 5484번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0529_03_L.jpg
# 5486번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0529_03_L.jpg
# 5494번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0529_03_R.jpg
# 5496번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0529_03_R.jpg
# 5538번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0536_01_L30.jpg
# 5574번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0536_02_L.jpg
# 5584번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0536_02_R.jpg
# 5593번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0536_03_F.jpg
# 5601번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0536_03_L.jpg
# 5611번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0536_03_R.jpg
# 5655번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0538_01_L30.jpg
# 5674번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0538_01_R30.jpg
# 5691번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0538_02_L.jpg
# 5701번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0538_02_R.jpg
# 5718번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0538_03_L.jpg
# 5720번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0538_03_L.jpg
# 5728번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0538_03_R.jpg
# 5772번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0560_01_L30.jpg
# 5808번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0560_02_L.jpg
# 5818번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0560_02_R.jpg
# 5835번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0560_03_L.jpg
# 5845번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0560_03_R.jpg
# 5889번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0566_01_L30.jpg
# 5925번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0566_02_L.jpg
# 5935번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0566_02_R.jpg
# 5952번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0566_03_L.jpg
# 5954번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0566_03_L.jpg
# 5962번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0566_03_R.jpg
# 6006번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0568_01_L30.jpg
# 6042번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0568_02_L.jpg
# 6052번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0568_02_R.jpg
# 6069번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0568_03_L.jpg
# 6071번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0568_03_L.jpg
# 6079번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0568_03_R.jpg
# 6081번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0568_03_R.jpg
# 6123번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0569_01_L30.jpg
# 6142번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0569_01_R30.jpg
# 6159번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0569_02_L.jpg
# 6169번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0569_02_R.jpg
# 6186번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0569_03_L.jpg
# 6196번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0569_03_R.jpg
# 6198번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0569_03_R.jpg
# 6240번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0583_01_L30.jpg
# 6276번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0583_02_L.jpg
# 6286번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0583_02_R.jpg
# 6303번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0583_03_L.jpg
# 6313번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0583_03_R.jpg
# 6376번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0591_01_R30.jpg
# 6393번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0591_02_L.jpg
# 6403번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0591_02_R.jpg
# 6430번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0591_03_R.jpg
# 6474번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0614_01_L30.jpg
# 6493번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0614_01_R30.jpg
# 6510번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0614_02_L.jpg
# 6512번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0614_02_L.jpg
# 6520번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0614_02_R.jpg
# 6537번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0614_03_L.jpg
# 6539번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0614_03_L.jpg
# 6547번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0614_03_R.jpg
# 6549번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0614_03_R.jpg
# 6579번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_L15.jpg
# 6580번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_L15.jpg
# 6581번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_L15.jpg
# 6582번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_L15.jpg
# 6583번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_L15.jpg
# 6584번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_L15.jpg
# 6585번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_L15.jpg
# 6586번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_L15.jpg
# 6587번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_L15.jpg
# 6591번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_01_L30.jpg
# 6606번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_R30.jpg
# 6607번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_R30.jpg
# 6608번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_R30.jpg
# 6609번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_R30.jpg
# 6610번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_R30.jpg
# 6611번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_R30.jpg
# 6612번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_R30.jpg
# 6613번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_R30.jpg
# 6614번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0615_01_R30.jpg
# 6627번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_02_L.jpg
# 6629번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_02_L.jpg
# 6637번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_02_R.jpg
# 6645번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_03_F.jpg
# 6646번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_03_F.jpg
# 6653번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_03_L.jpg
# 6654번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_03_L.jpg
# 6656번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_03_L.jpg
# 6661번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_03_R.jpg
# 6662번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_03_R.jpg
# 6664번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_03_R.jpg
# 6666번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0615_03_R.jpg
# 6678번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0627_01_Ft.jpg
# 6679번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0627_01_Ft.jpg
# 6680번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0627_01_Ft.jpg
# 6681번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0627_01_Ft.jpg
# 6682번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0627_01_Ft.jpg
# 6683번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0627_01_Ft.jpg
# 6684번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0627_01_Ft.jpg
# 6685번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0627_01_Ft.jpg
# 6686번 행을 건너뜁니다. 이미지 파일이 존재하지 않습니다: 0627_01_Ft.jpg
# 6708번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0627_01_L30.jpg
# 6727번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0627_01_R30.jpg
# 6744번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0627_02_L.jpg
# 6754번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0627_02_R.jpg
# 6771번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0627_03_L.jpg
# 6773번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0627_03_L.jpg
# 6781번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0627_03_R.jpg
# 6783번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0627_03_R.jpg
# 6825번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0630_01_L30.jpg
# 6844번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0630_01_R30.jpg
# 6861번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0630_02_L.jpg
# 6871번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0630_02_R.jpg
# 6888번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0630_03_L.jpg
# 6898번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0630_03_R.jpg
# 7005번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0657_03_L.jpg
# 7015번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0657_03_R.jpg
# 7017번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0657_03_R.jpg
# 7059번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0659_01_L30.jpg
# 7095번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0659_02_L.jpg
# 7105번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0659_02_R.jpg
# 7122번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0659_03_L.jpg
# 7132번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0659_03_R.jpg
# 7134번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0659_03_R.jpg
# 7176번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0671_01_L30.jpg
# 7212번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0671_02_L.jpg
# 7222번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0671_02_R.jpg
# 7239번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0671_03_L.jpg
# 7249번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0671_03_R.jpg
# 7329번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0673_02_L.jpg
# 7339번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0673_02_R.jpg
# 7356번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0673_03_L.jpg
# 7366번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0673_03_R.jpg
# 7410번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0675_01_L30.jpg
# 7446번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0675_02_L.jpg
# 7527번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0715_01_L30.jpg
# 7563번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0715_02_L.jpg
# 7573번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0715_02_R.jpg
# 7590번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0715_03_L.jpg
# 7600번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0715_03_R.jpg
# 7602번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0715_03_R.jpg
# 7680번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0753_02_L.jpg
# 7690번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0753_02_R.jpg
# 7707번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0753_03_L.jpg
# 7709번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0753_03_L.jpg
# 7717번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0753_03_R.jpg
# 7719번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0753_03_R.jpg
# 7797번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0755_02_L.jpg
# 7807번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0755_02_R.jpg
# 7824번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0755_03_L.jpg
# 7826번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0755_03_L.jpg
# 7834번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0755_03_R.jpg
# 7836번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0755_03_R.jpg
# 7914번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0756_02_L.jpg
# 7924번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0756_02_R.jpg
# 7941번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0756_03_L.jpg
# 7943번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0756_03_L.jpg
# 7951번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0756_03_R.jpg
# 7953번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0756_03_R.jpg
# 8031번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0766_02_L.jpg
# 8050번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0766_03_F.jpg
# 8058번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0766_03_L.jpg
# 8068번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0766_03_R.jpg
# 8131번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0779_01_R30.jpg
# 8148번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0779_02_L.jpg
# 8158번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0779_02_R.jpg
# 8175번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0779_03_L.jpg
# 8185번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0779_03_R.jpg
# 8187번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0779_03_R.jpg
# 8229번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0781_01_L30.jpg
# 8248번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0781_01_R30.jpg
# 8265번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0781_02_L.jpg
# 8275번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0781_02_R.jpg
# 8292번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0781_03_L.jpg
# 8294번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0781_03_L.jpg
# 8302번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0781_03_R.jpg
# 8304번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0781_03_R.jpg
# 8346번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0785_01_L30.jpg
# 8382번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0785_02_L.jpg
# 8392번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0785_02_R.jpg
# 8463번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0790_01_L30.jpg
# 8482번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0790_01_R30.jpg
# 8499번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0790_02_L.jpg
# 8509번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0790_02_R.jpg
# 8580번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0797_01_L30.jpg
# 8599번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0797_01_R30.jpg
# 8616번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0797_02_L.jpg
# 8626번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0797_02_R.jpg
# 8643번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0797_03_L.jpg
# 8645번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0797_03_L.jpg
# 8653번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0797_03_R.jpg
# 8655번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0797_03_R.jpg
# 8697번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0804_01_L30.jpg
# 8716번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0804_01_R30.jpg
# 8733번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0804_02_L.jpg
# 8743번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0804_02_R.jpg
# 8760번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0804_03_L.jpg
# 8770번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0804_03_R.jpg
# 8850번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0814_02_L.jpg
# 8860번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0814_02_R.jpg
# 8877번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0814_03_L.jpg
# 8887번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0814_03_R.jpg
# 8967번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0828_02_L.jpg
# 8977번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0828_02_R.jpg
# 8994번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0828_03_L.jpg
# 9004번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0828_03_R.jpg
# 9048번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0843_01_L30.jpg
# 9067번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0843_01_R30.jpg
# 9084번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0843_02_L.jpg
# 9094번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0843_02_R.jpg
# 9111번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0843_03_L.jpg
# 9121번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0843_03_R.jpg
# 9165번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0852_01_L30.jpg
# 9201번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0852_02_L.jpg
# 9211번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0852_02_R.jpg
# 9228번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0852_03_L.jpg
# 9230번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0852_03_L.jpg
# 9238번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0852_03_R.jpg
# 9240번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0852_03_R.jpg
# 9282번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0868_01_L30.jpg
# 9318번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0868_02_L.jpg
# 9328번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0868_02_R.jpg
# 9345번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0868_03_L.jpg
# 9347번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0868_03_L.jpg
# 9355번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0868_03_R.jpg
# 9357번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0868_03_R.jpg
# 9399번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0878_01_L30.jpg
# 9418번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0878_01_R30.jpg
# 9435번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0878_02_L.jpg
# 9445번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0878_02_R.jpg
# 9453번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0878_03_F.jpg
# 9454번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0878_03_F.jpg
# 9462번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0878_03_L.jpg
# 9464번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0878_03_L.jpg
# 9472번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0878_03_R.jpg
# 9474번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0878_03_R.jpg
# 9516번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0898_01_L30.jpg
# 9535번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0898_01_R30.jpg
# 9543번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0898_02_F.jpg
# 9552번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0898_02_L.jpg
# 9562번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0898_02_R.jpg
# 9570번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0898_03_F.jpg
# 9579번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0898_03_L.jpg
# 9589번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0898_03_R.jpg
# 9633번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0909_01_L30.jpg
# 9652번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0909_01_R30.jpg
# 9669번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0909_02_L.jpg
# 9679번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0909_02_R.jpg
# 9688번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0909_03_F.jpg
# 9696번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0909_03_L.jpg
# 9698번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0909_03_L.jpg
# 9706번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0909_03_R.jpg
# 9708번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0909_03_R.jpg
# 9750번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0911_01_L30.jpg
# 9786번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0911_02_L.jpg
# 9796번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0911_02_R.jpg
# 9813번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0911_03_L.jpg
# 9823번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0911_03_R.jpg
# 9867번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0913_01_L30.jpg
# 9903번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0913_02_L.jpg
# 9913번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0913_02_R.jpg
# 9930번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0913_03_L.jpg
# 9932번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0913_03_L.jpg
# 9940번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0913_03_R.jpg
# 9984번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0922_01_L30.jpg
# 10003번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0922_01_R30.jpg
# 10020번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0922_02_L.jpg
# 10030번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0922_02_R.jpg
# 10047번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0922_03_L.jpg
# 10057번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0922_03_R.jpg
# 10101번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0923_01_L30.jpg
# 10137번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0923_02_L.jpg
# 10147번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0923_02_R.jpg
# 10164번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0923_03_L.jpg
# 10174번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0923_03_R.jpg
# 10218번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0944_01_L30.jpg
# 10254번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0944_02_L.jpg
# 10264번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0944_02_R.jpg
# 10281번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0944_03_L.jpg
# 10291번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0944_03_R.jpg
# 10335번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0946_01_L30.jpg
# 10371번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0946_02_L.jpg
# 10381번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0946_02_R.jpg
# 10398번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0946_03_L.jpg
# 10408번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0946_03_R.jpg
# 10488번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0951_02_L.jpg
# 10498번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0951_02_R.jpg
# 10515번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0951_03_L.jpg
# 10525번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0951_03_R.jpg
# 10605번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0954_02_L.jpg
# 10615번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0954_02_R.jpg
# 10632번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0954_03_L.jpg
# 10642번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0954_03_R.jpg
# 10686번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0969_01_L30.jpg
# 10722번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0969_02_L.jpg
# 10732번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0969_02_R.jpg
# 10749번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0969_03_L.jpg
# 10751번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0969_03_L.jpg
# 10759번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0969_03_R.jpg
# 10803번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0980_01_L30.jpg
# 10822번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0980_01_R30.jpg
# 10839번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0980_02_L.jpg
# 10849번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0980_02_R.jpg
# 10858번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0980_03_F.jpg
# 10866번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0980_03_L.jpg
# 10868번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0980_03_L.jpg
# 10876번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0980_03_R.jpg
# 10878번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0980_03_R.jpg
# 10920번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0988_01_L30.jpg
# 10939번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0988_01_R30.jpg
# 10948번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0988_02_F.jpg
# 10956번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0988_02_L.jpg
# 10966번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0988_02_R.jpg
# 10983번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0988_03_L.jpg
# 10993번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0988_03_R.jpg
# 11037번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0990_01_L30.jpg
# 11056번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0990_01_R30.jpg
# 11073번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0990_02_L.jpg
# 11083번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0990_02_R.jpg
# 11100번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0990_03_L.jpg
# 11110번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0990_03_R.jpg
# 11190번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1006_02_L.jpg
# 11200번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1006_02_R.jpg
# 11217번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1006_03_L.jpg
# 11227번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1006_03_R.jpg
# 11229번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1006_03_R.jpg
# 11271번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1020_01_L30.jpg
# 11307번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1020_02_L.jpg
# 11317번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1020_02_R.jpg
# 11334번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1020_03_L.jpg
# 11344번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1020_03_R.jpg
# 11388번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1036_01_L30.jpg
# 11424번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1036_02_L.jpg
# 11434번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1036_02_R.jpg
# 11451번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1036_03_L.jpg
# 11505번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1045_01_L30.jpg
# 11541번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1045_02_L.jpg
# 11551번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1045_02_R.jpg
# 11568번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1045_03_L.jpg
# 11578번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1045_03_R.jpg
# 11622번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1052_01_L30.jpg
# 11641번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1052_01_R30.jpg
# 11658번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1052_02_L.jpg
# 11668번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1052_02_R.jpg
# 11685번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1052_03_L.jpg
# 11695번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1052_03_R.jpg
# 11739번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1055_01_L30.jpg
# 11758번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1055_01_R30.jpg
# 11775번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1055_02_L.jpg
# 11785번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1055_02_R.jpg
# 11802번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1055_03_L.jpg
# 11812번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1055_03_R.jpg
# 11892번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1056_02_L.jpg
# 11902번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1056_02_R.jpg
# 11929번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1056_03_R.jpg
# 11973번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1060_01_L30.jpg
# 12009번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1060_02_L.jpg
# 12019번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1060_02_R.jpg
# 12036번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1060_03_L.jpg
# 12046번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1060_03_R.jpg
# 12109번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1065_01_R30.jpg
# 12126번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1065_02_L.jpg
# 12136번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1065_02_R.jpg
# 12153번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1065_03_L.jpg
# 12163번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1065_03_R.jpg
# 12207번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1076_01_L30.jpg
# 12226번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1076_01_R30.jpg
# 12243번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1076_02_L.jpg
# 12253번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1076_02_R.jpg
# 12270번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1076_03_L.jpg
# 12280번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1076_03_R.jpg
# 12324번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1081_01_L30.jpg
# 12343번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1081_01_R30.jpg
# 12360번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1081_02_L.jpg
# 12370번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1081_02_R.jpg
# 12387번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1081_03_L.jpg
# 12397번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1081_03_R.jpg
# 12441번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1091_01_L30.jpg
# 12460번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1091_01_R30.jpg
# 12477번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1091_02_L.jpg
# 12487번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1091_02_R.jpg
# 12504번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1091_03_L.jpg
# 12514번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1091_03_R.jpg
# 12577번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0002_01_R30.jpg
# 12594번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0002_02_L.jpg
# 12604번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0002_02_R.jpg
# 12621번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0002_03_L.jpg
# 12623번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0002_03_L.jpg
# 12631번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0002_03_R.jpg
# 12633번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0002_03_R.jpg
# 12694번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_01_R30.jpg
# 12711번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_02_L.jpg
# 12721번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_02_R.jpg
# 12728번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_F.jpg
# 12729번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_F.jpg
# 12730번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_F.jpg
# 12731번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_F.jpg
# 12733번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_F.jpg
# 12737번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_L.jpg
# 12738번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_L.jpg
# 12739번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_L.jpg
# 12740번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_L.jpg
# 12742번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_L.jpg
# 12746번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_R.jpg
# 12747번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_R.jpg
# 12748번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_R.jpg
# 12750번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_R.jpg
# 12751번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0003_03_R.jpg
# 12792번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0006_01_L30.jpg
# 12811번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0006_01_R30.jpg
# 12828번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0006_02_L.jpg
# 12838번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0006_02_R.jpg
# 12846번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0006_03_F.jpg
# 12847번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0006_03_F.jpg
# 12855번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0006_03_L.jpg
# 12857번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0006_03_L.jpg
# 12865번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0006_03_R.jpg
# 12909번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0007_01_L30.jpg
# 12928번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0007_01_R30.jpg
# 12945번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0007_02_L.jpg
# 12955번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0007_02_R.jpg
# 12972번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0007_03_L.jpg
# 12982번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0007_03_R.jpg
# 13017번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0008_01_L15.jpg
# 13026번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0008_01_L30.jpg
# 13045번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0008_01_R30.jpg
# 13062번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0008_02_L.jpg
# 13072번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0008_02_R.jpg
# 13080번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0008_03_F.jpg
# 13081번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0008_03_F.jpg
# 13089번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0008_03_L.jpg
# 13099번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0008_03_R.jpg
# 13101번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0008_03_R.jpg
# 13134번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0009_01_L15.jpg
# 13143번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0009_01_L30.jpg
# 13162번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0009_01_R30.jpg
# 13179번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0009_02_L.jpg
# 13189번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0009_02_R.jpg
# 13206번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0009_03_L.jpg
# 13208번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0009_03_L.jpg
# 13216번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0009_03_R.jpg
# 13218번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0009_03_R.jpg
# 13251번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0010_01_L15.jpg
# 13260번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0010_01_L30.jpg
# 13279번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0010_01_R30.jpg
# 13296번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0010_02_L.jpg
# 13306번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0010_02_R.jpg
# 13323번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0010_03_L.jpg
# 13333번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0010_03_R.jpg
# 13368번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0011_01_L15.jpg
# 13377번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0011_01_L30.jpg
# 13396번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0011_01_R30.jpg
# 13413번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0011_02_L.jpg
# 13423번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0011_02_R.jpg
# 13440번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0011_03_L.jpg
# 13450번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0011_03_R.jpg
# 13485번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0012_01_L15.jpg
# 13494번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0012_01_L30.jpg
# 13513번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0012_01_R30.jpg
# 13530번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0012_02_L.jpg
# 13540번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0012_02_R.jpg
# 13557번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0012_03_L.jpg
# 13567번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0012_03_R.jpg
# 13602번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0014_01_L15.jpg
# 13611번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0014_01_L30.jpg
# 13630번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0014_01_R30.jpg
# 13647번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0014_02_L.jpg
# 13657번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0014_02_R.jpg
# 13674번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0014_03_L.jpg
# 13684번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0014_03_R.jpg
# 13719번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0016_01_L15.jpg
# 13728번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0016_01_L30.jpg
# 13747번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0016_01_R30.jpg
# 13764번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0016_02_L.jpg
# 13774번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0016_02_R.jpg
# 13782번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0016_03_F.jpg
# 13791번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0016_03_L.jpg
# 13793번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0016_03_L.jpg
# 13801번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0016_03_R.jpg
# 13803번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0016_03_R.jpg
# 13836번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0017_01_L15.jpg
# 13845번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0017_01_L30.jpg
# 13864번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0017_01_R30.jpg
# 13881번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0017_02_L.jpg
# 13891번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0017_02_R.jpg
# 13908번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0017_03_L.jpg
# 13910번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0017_03_L.jpg
# 13918번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0017_03_R.jpg
# 13920번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0017_03_R.jpg
# 13953번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0018_01_L15.jpg
# 13962번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0018_01_L30.jpg
# 13981번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0018_01_R30.jpg
# 13998번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0018_02_L.jpg
# 14008번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0018_02_R.jpg
# 14025번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0018_03_L.jpg
# 14035번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0018_03_R.jpg
# 14070번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0019_01_L15.jpg
# 14079번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0019_01_L30.jpg
# 14098번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0019_01_R30.jpg
# 14115번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0019_02_L.jpg
# 14125번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0019_02_R.jpg
# 14142번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0019_03_L.jpg
# 14152번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0019_03_R.jpg
# 14196번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0020_01_L30.jpg
# 14215번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0020_01_R30.jpg
# 14232번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0020_02_L.jpg
# 14242번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0020_02_R.jpg
# 14259번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0020_03_L.jpg
# 14269번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0020_03_R.jpg
# 14332번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_01_R30.jpg
# 14349번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_02_L.jpg
# 14359번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_02_R.jpg
# 14365번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_F.jpg
# 14366번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_F.jpg
# 14367번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_F.jpg
# 14368번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_F.jpg
# 14371번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_F.jpg
# 14374번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_L.jpg
# 14375번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_L.jpg
# 14376번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_L.jpg
# 14377번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_L.jpg
# 14378번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_L.jpg
# 14380번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_L.jpg
# 14383번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_R.jpg
# 14384번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_R.jpg
# 14385번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_R.jpg
# 14386번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_R.jpg
# 14388번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_R.jpg
# 14389번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0022_03_R.jpg
# 14430번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0023_01_L30.jpg
# 14449번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0023_01_R30.jpg
# 14466번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0023_02_L.jpg
# 14476번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0023_02_R.jpg
# 14485번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0023_03_F.jpg
# 14493번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0023_03_L.jpg
# 14503번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0023_03_R.jpg
# 14547번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0024_01_L30.jpg
# 14583번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0024_02_L.jpg
# 14593번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0024_02_R.jpg
# 14610번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0024_03_L.jpg
# 14620번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0024_03_R.jpg
# 14664번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0025_01_L30.jpg
# 14683번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0025_01_R30.jpg
# 14700번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0025_02_L.jpg
# 14710번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0025_02_R.jpg
# 14727번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0025_03_L.jpg
# 14737번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0025_03_R.jpg
# 14781번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0026_01_L30.jpg
# 14800번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0026_01_R30.jpg
# 14817번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0026_02_L.jpg
# 14827번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0026_02_R.jpg
# 14844번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0026_03_L.jpg
# 14846번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0026_03_L.jpg
# 14854번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0026_03_R.jpg
# 14898번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0027_01_L30.jpg
# 14917번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0027_01_R30.jpg
# 14934번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0027_02_L.jpg
# 14944번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0027_02_R.jpg
# 14961번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0027_03_L.jpg
# 14971번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0027_03_R.jpg
# 14973번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0027_03_R.jpg
# 15015번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0028_01_L30.jpg
# 15034번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0028_01_R30.jpg
# 15051번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0028_02_L.jpg
# 15061번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0028_02_R.jpg
# 15078번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0028_03_L.jpg
# 15080번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0028_03_L.jpg
# 15088번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0028_03_R.jpg
# 15090번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0028_03_R.jpg
# 15132번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0029_01_L30.jpg
# 15151번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0029_01_R30.jpg
# 15168번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0029_02_L.jpg
# 15178번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0029_02_R.jpg
# 15195번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0029_03_L.jpg
# 15205번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0029_03_R.jpg
# 15249번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_01_L30.jpg
# 15268번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_01_R30.jpg
# 15285번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_02_L.jpg
# 15295번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_02_R.jpg
# 15303번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_03_F.jpg
# 15304번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_03_F.jpg
# 15307번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_03_F.jpg
# 15312번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_03_L.jpg
# 15314번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_03_L.jpg
# 15316번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_03_L.jpg
# 15322번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_03_R.jpg
# 15324번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_03_R.jpg
# 15325번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0030_03_R.jpg
# 15385번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0031_01_R30.jpg
# 15402번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0031_02_L.jpg
# 15412번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0031_02_R.jpg
# 15429번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0031_03_L.jpg
# 15439번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0031_03_R.jpg
# 15483번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0032_01_L30.jpg
# 15502번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0032_01_R30.jpg
# 15519번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0032_02_L.jpg
# 15529번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0032_02_R.jpg
# 15546번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0032_03_L.jpg
# 15548번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0032_03_L.jpg
# 15556번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0032_03_R.jpg
# 15591번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0033_01_L15.jpg
# 15600번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0033_01_L30.jpg
# 15619번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0033_01_R30.jpg
# 15636번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0033_02_L.jpg
# 15646번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0033_02_R.jpg
# 15663번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0033_03_L.jpg
# 15673번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0033_03_R.jpg
# 15717번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0035_01_L30.jpg
# 15736번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0035_01_R30.jpg
# 15753번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0035_02_L.jpg
# 15763번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0035_02_R.jpg
# 15780번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0035_03_L.jpg
# 15790번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0035_03_R.jpg
# 15792번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0035_03_R.jpg
# 15853번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0036_01_R30.jpg
# 15870번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0036_02_L.jpg
# 15880번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0036_02_R.jpg
# 15897번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0036_03_L.jpg
# 15907번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0036_03_R.jpg
# 15970번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0037_01_R30.jpg
# 15987번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0037_02_L.jpg
# 15997번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0037_02_R.jpg
# 16014번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0037_03_L.jpg
# 16024번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0037_03_R.jpg
# 16087번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0038_01_R30.jpg
# 16104번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0038_02_L.jpg
# 16114번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0038_02_R.jpg
# 16131번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0038_03_L.jpg
# 16141번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0038_03_R.jpg
# 16204번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0039_01_R30.jpg
# 16221번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0039_02_L.jpg
# 16231번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0039_02_R.jpg
# 16248번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0039_03_L.jpg
# 16258번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0039_03_R.jpg
# 16260번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0039_03_R.jpg
# 16321번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 0040_01_R30.jpg
# ...
# 109353번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1062_02_L.jpg
# 109363번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1062_02_R.jpg
# 109380번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1062_03_L.jpg
# 109382번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1062_03_L.jpg
# 109390번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1062_03_R.jpg
# 109434번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1064_01_L30.jpg
# 109453번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1064_01_R30.jpg
# 109470번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1064_02_L.jpg
# 109480번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1064_02_R.jpg
# 109497번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1064_03_L.jpg
# 109499번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1064_03_L.jpg
# 109507번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1064_03_R.jpg
# 109551번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1068_01_L30.jpg
# 109570번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1068_01_R30.jpg
# 109587번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1068_02_L.jpg
# 109597번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1068_02_R.jpg
# 109612번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1068_03_L.jpg
# 109614번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1068_03_L.jpg
# 109616번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1068_03_L.jpg
# 109624번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1068_03_R.jpg
# 109626번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1068_03_R.jpg
# 109668번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1069_01_L30.jpg
# 109687번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1069_01_R30.jpg
# 109704번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1069_02_L.jpg
# 109714번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1069_02_R.jpg
# 109731번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1069_03_L.jpg
# 109741번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1069_03_R.jpg
# 109785번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1070_01_L30.jpg
# 109804번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1070_01_R30.jpg
# 109821번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1070_02_L.jpg
# 109831번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1070_02_R.jpg
# 109848번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1070_03_L.jpg
# 109858번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1070_03_R.jpg
# 109902번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1071_01_L30.jpg
# 109938번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1071_02_L.jpg
# 109948번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1071_02_R.jpg
# 109965번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1071_03_L.jpg
# 109975번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1071_03_R.jpg
# 110019번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1072_01_L30.jpg
# 110055번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1072_02_L.jpg
# 110065번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1072_02_R.jpg
# 110082번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1072_03_L.jpg
# 110092번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1072_03_R.jpg
# 110136번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1073_01_L30.jpg
# 110155번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1073_01_R30.jpg
# 110172번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1073_02_L.jpg
# 110182번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1073_02_R.jpg
# 110199번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1073_03_L.jpg
# 110209번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1073_03_R.jpg
# 110253번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1074_01_L30.jpg
# 110272번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1074_01_R30.jpg
# 110289번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1074_02_L.jpg
# 110299번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1074_02_R.jpg
# 110301번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1074_02_R.jpg
# 110316번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1074_03_L.jpg
# 110326번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1074_03_R.jpg
# 110370번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1075_01_L30.jpg
# 110389번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1075_01_R30.jpg
# 110406번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1075_02_L.jpg
# 110416번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1075_02_R.jpg
# 110433번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1075_03_L.jpg
# 110443번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1075_03_R.jpg
# 110487번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1077_01_L30.jpg
# 110523번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1077_02_L.jpg
# 110533번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1077_02_R.jpg
# 110550번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1077_03_L.jpg
# 110560번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1077_03_R.jpg
# 110604번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1078_01_L30.jpg
# 110623번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1078_01_R30.jpg
# 110640번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1078_02_L.jpg
# 110650번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1078_02_R.jpg
# 110667번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1078_03_L.jpg
# 110677번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1078_03_R.jpg
# 110721번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1079_01_L30.jpg
# 110740번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1079_01_R30.jpg
# 110757번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1079_02_L.jpg
# 110767번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1079_02_R.jpg
# 110784번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1079_03_L.jpg
# 110794번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1079_03_R.jpg
# 110796번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1079_03_R.jpg
# 110884번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1082_02_R.jpg
# 110901번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1082_03_L.jpg
# 110911번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1082_03_R.jpg
# 110913번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1082_03_R.jpg
# 110955번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1083_01_L30.jpg
# 110974번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1083_01_R30.jpg
# 110991번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1083_02_L.jpg
# 111001번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1083_02_R.jpg
# 111018번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1083_03_L.jpg
# 111028번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1083_03_R.jpg
# 111072번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1084_01_L30.jpg
# 111091번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1084_01_R30.jpg
# 111108번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1084_02_L.jpg
# 111118번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1084_02_R.jpg
# 111135번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1084_03_L.jpg
# 111145번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1084_03_R.jpg
# 111225번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1085_02_L.jpg
# 111235번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1085_02_R.jpg
# 111252번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1085_03_L.jpg
# 111262번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1085_03_R.jpg
# 111342번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1086_02_L.jpg
# 111352번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1086_02_R.jpg
# 111369번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1086_03_L.jpg
# 111371번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1086_03_L.jpg
# 111379번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1086_03_R.jpg
# 111381번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1086_03_R.jpg
# 111423번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1087_01_L30.jpg
# 111442번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1087_01_R30.jpg
# 111459번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1087_02_L.jpg
# 111469번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1087_02_R.jpg
# 111486번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1087_03_L.jpg
# 111496번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1087_03_R.jpg
# 111540번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1088_01_L30.jpg
# 111559번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1088_01_R30.jpg
# 111576번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1088_02_L.jpg
# 111586번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1088_02_R.jpg
# 111603번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1088_03_L.jpg
# 111613번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1088_03_R.jpg
# 111657번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1089_01_L30.jpg
# 111676번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1089_01_R30.jpg
# 111693번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1089_02_L.jpg
# 111703번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1089_02_R.jpg
# 111720번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1089_03_L.jpg
# 111730번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1089_03_R.jpg
# 111810번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1090_02_L.jpg
# 111820번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1090_02_R.jpg
# 111837번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1090_03_L.jpg
# 111847번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1090_03_R.jpg
# 111891번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1092_01_L30.jpg
# 111910번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1092_01_R30.jpg
# 111927번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1092_02_L.jpg
# 111937번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1092_02_R.jpg
# 111954번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1092_03_L.jpg
# 111964번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1092_03_R.jpg
# 112008번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1093_01_L30.jpg
# 112027번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1093_01_R30.jpg
# 112044번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1093_02_L.jpg
# 112054번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1093_02_R.jpg
# 112071번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1093_03_L.jpg
# 112081번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1093_03_R.jpg
# 112161번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1094_02_L.jpg
# 112171번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1094_02_R.jpg
# 112188번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1094_03_L.jpg
# 112190번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1094_03_L.jpg
# 112198번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1094_03_R.jpg
# 112200번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1094_03_R.jpg
# 112278번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1095_02_L.jpg
# 112288번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1095_02_R.jpg
# 112305번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1095_03_L.jpg
# 112315번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1095_03_R.jpg
# 112359번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1096_01_L30.jpg
# 112378번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1096_01_R30.jpg
# 112395번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1096_02_L.jpg
# 112405번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1096_02_R.jpg
# 112422번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1096_03_L.jpg
# 112432번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1096_03_R.jpg
# 112476번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1097_01_L30.jpg
# 112512번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1097_02_L.jpg
# 112522번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1097_02_R.jpg
# 112539번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1097_03_L.jpg
# 112549번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1097_03_R.jpg
# 112593번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1098_01_L30.jpg
# 112629번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1098_02_L.jpg
# 112639번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1098_02_R.jpg
# 112656번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1098_03_L.jpg
# 112666번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1098_03_R.jpg
# 112710번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1099_01_L30.jpg
# 112746번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1099_02_L.jpg
# 112756번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1099_02_R.jpg
# 112773번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1099_03_L.jpg
# 112783번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1099_03_R.jpg
# 112827번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1100_01_L30.jpg
# 112863번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1100_02_L.jpg
# 112873번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1100_02_R.jpg
# 112890번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1100_03_L.jpg
# 112900번 행을 건너뜁니다. 파일에 대한 필수 정보가 누락되었습니다: 1100_03_R.jpg
# 총 107256개의 이미지를 처리했습니다.
# Ultralytics YOLOv8.2.50  Python-3.11.7 torch-2.3.1+cpu CPU (Intel Core(TM) i3-7100U 2.40GHz)
# engine\trainer: task=detect, mode=train, model=yolov8n.yaml, data=C:\workspace_multi07\web\15_final project\data\dataset.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train2
# Overriding model.yaml nc=80 with nc=9
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753067  ultralytics.nn.modules.head.Detect           [9, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3012603 parameters, 3012587 gradients, 8.2 GFLOPs
#
# TensorBoard: Start with 'tensorboard --logdir runs\detect\train2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning C:\workspace_multi07\web\15_final project\data\Training\labels... 11154 images, 0 backgrounds, 1 corrup
# train: WARNING  C:\workspace_multi07\web\15_final project\data\Training\images\0972_01_L15.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0435]
# train: New cache created: C:\workspace_multi07\web\15_final project\data\Training\labels.cache
# val: Scanning C:\workspace_multi07\web\15_final project\data\Validation\labels... 1387 images, 0 backgrounds, 1 corrupt
# val: WARNING  C:\workspace_multi07\web\15_final project\data\Validation\images\0615_01_L30.jpg: ignoring corrupt image/label: image file is truncated (96 bytes not processed)
# val: New cache created: C:\workspace_multi07\web\15_final project\data\Validation\labels.cache
# Plotting labels to runs\detect\train2\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000769, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train2
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30         0G      3.851      4.514      4.229        262        640:   1%|▏         | 10/698 [05:21<5:39:46,

# %% [markdown]
# ### 딥러닝 및 나머지 코드

# %%
import os
import json
import numpy as np
import pandas as pd
from PIL import Image
from ultralytics import YOLO
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import logging
import yaml

# %%
# 로깅 설정
logging.basicConfig(filename='skin_analysis.log', level=logging.INFO, 
                    format='%(asctime)s:%(levelname)s:%(message)s')

# %%
# YOLO 모델 로드 함수
def load_yolo_model(model_path):
    return YOLO(model_path)

# %%
# 이미지를 224x224 크기로 로드 (ResNet50의 기본 입력 크기), 픽셀 값을 0~1 사이로 정규화
#  prepare_skin_data 함수에서 각 facepart 이미지를 로드할 때 사용
# 이미지 로드 및 전처리 함수
def load_and_preprocess_image(img_path):
    img = load_img(img_path, target_size=(224, 224))  # ResNet50의 기본 입력 크기
    img_array = img_to_array(img)
    img_array = img_array / 255.0  # 정규화
    return img_array

# %%
df.iloc[0]['images']['facepart']

# %%
# 피부 진단 데이터 준비 함수
def prepare_skin_data(df, facepart, base_path):
    # DataFrame에서 'Training' 데이터와 특정 facepart에 해당하는 데이터만 선택
    skin_data = df[(df['split'] == 'Training') & (df['images'].apply(lambda x: json.loads(x)['facepart'] == facepart))]
    
    X = []  # 이미지 데이터를 저장할 리스트
    y = []  # 라벨 데이터를 저장할 리스트
    
    for _, row in skin_data.iterrows():
        info = json.loads(row['info'])
        annotations = json.loads(row['annotations'])
        equipment = json.loads(row['equipment'])

        if facepart == 0:
            # facepart = 0은 얼굴 전체 이미지여서 원본 데이터 사용
            img_path = os.path.join(base_path, 'Training/01.원천데이터', info['filename'])
            # 이미지 로드 및 전처리
            img = load_and_preprocess_image(img_path)
            X.append(img)
            
        else:
            # 미리 자른 이미지 파일 경로
            img_path = os.path.join(base_path, 'Training_cropped', str(facepart), info['filename'])
            # 이미지 로드 및 전처리
            img = load_and_preprocess_image(img_path)
            X.append(img)
        
        # 라벨 데이터 준비
        if annotations is not None and equipment is not None:
            features = list(annotations.values()) + list(equipment.values())
            y.append(features)
        else:
            y.append([info['skin_type'], info['sensitive']])
    
    return np.array(X), np.array(y)

# %%
# CNN 모델 생성 함수
def create_cnn_model(input_shape, output_shape):
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(output_shape, activation='softmax')
    ])
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# ResNet50 모델 생성 함수(이건 분류모델   예측(회귀) 모델을 짜야한다)
def create_resnet50_model(input_shape, output_shape):
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dense(output_shape, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=x)
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# 피부 진단 모델 학습 함수
# 'Training'폴더 데이터만 사용 'Validation'폴더에 있는 데이터들은 서비스 구현 테스트할 때 최종테스트용
def train_skin_models(df, base_path, model_type='cnn'):
    skin_models = {}
    
    for facepart in range(9):
        X, y = prepare_skin_data(df, facepart, base_path)
        
        if len(X) == 0:
            continue
        
        # Training 데이터를 train과 validation으로 분할
        X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state= 0)
        
        input_shape = X_train.shape[1:]
        output_shape = y_train.shape[1]
        
        if model_type == 'cnn':
            model = create_cnn_model(input_shape, output_shape)
        elif model_type == 'resnet50':
            model = create_resnet50_model(input_shape, output_shape)
        else:
            raise ValueError("Invalid model type. Choose 'cnn' or 'resnet50'.")
        
        # 이미지 데이터 증강
        datagen = ImageDataGenerator(
            rotation_range=20,
            width_shift_range=0.2,
            height_shift_range=0.2,
            horizontal_flip=True
        )
        
        # 모델 학습
        model.fit(datagen.flow(X_train, y_train, batch_size=32),
                  epochs=50,
                  validation_data=(X_val, y_val))
        
        skin_models[facepart] = model
    
    return skin_models

# %%
# 이미지에서 얼굴 부위 추출 함수
def extract_faceparts(image, yolo_model):
    results = yolo_model(image)
    faceparts = []
    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            facepart = image[int(y1):int(y2), int(x1):int(x2)]
            faceparts.append(facepart)
    return faceparts

# %%
# 피부 상태 예측 함수
def predict_skin_condition(image_path, yolo_model, skin_models):
    image = load_img(image_path)
    image = img_to_array(image)
    
    faceparts = extract_faceparts(image, yolo_model)
    
    predictions = {}
    for i, facepart in enumerate(faceparts):
        facepart = load_and_preprocess_image(facepart)
        facepart = np.expand_dims(facepart, axis=0)
        
        if i in skin_models:
            prediction = skin_models[i].predict(facepart)
            predictions[i] = prediction[0]
    
    return predictions

# %%
# 메인 실행 코드
if __name__ == "__main__":
    base_path = os.path.abspath('data') # 데이터 경로

    # 피부 진단 모델 학습 (CNN 사용)
    skin_models_cnn = train_skin_models(df, base_path, model_type='cnn')

    # 피부 진단 모델 학습 (ResNet50 사용)
    skin_models_resnet = train_skin_models(df, base_path, model_type='resnet50')

    # 모델 저장
    for facepart, model in skin_models_cnn.items():
        model.save(f'skin_model_cnn_{facepart}.h5')
    for facepart, model in skin_models_resnet.items():
        model.save(f'skin_model_resnet_{facepart}.h5')

    print("모든 모델 학습 완료")

# %%
    yolo_model_path = 'path/to/your/trained_yolo_model.pt' # 학습한 yolo 모델 path
    # YOLO 모델 로드 (이미 학습된 모델 사용)
    yolo_model = load_yolo_model(yolo_model_path)

    # Validation 데이터셋의 이미지들에 대해 예측 실행
    validation_image_path = os.path.join(base_path, 'Validation', '01.원천데이터')
    for image_file in os.listdir(validation_image_path):
        if image_file.endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(validation_image_path, image_file)
            predictions = predict_skin_condition(image_path, yolo_model, skin_models_cnn)  # 또는 skin_models_resnet
            print(f"이미지 {image_file}의 예측 결과:", predictions)
