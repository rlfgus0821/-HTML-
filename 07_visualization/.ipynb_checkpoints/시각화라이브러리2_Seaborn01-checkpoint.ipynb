# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 한글 폰트 지원
import platform
from matplotlib import font_manager, rc

plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %% [markdown]
# # Seaborn

# %% [markdown]
# - matplotlib의 기능에 스타일을 확장한 파이썬 시각화 도구
# - high-level interface
# - 패키지는 설치해야 함(pip install seaborn)
#     - 아나콘다에 seaborn 패키지 포함되어 있으므로 이미 설치되어 있음
# - seaborn을 사용하기 위해서는 matplotlib가 import 되어 있어야 함

# %% [markdown]
# ## 지원되는 플롯 유형
#
# - Relational plots
# - Distribution plots
# - Categorical plots
# - Regression plots
# - Multi-plot grids
# - Figure theming
# - Color palettes

# %% [markdown]
# ------------------------

# %% [markdown]
# # 시각화의 목적에 따른 플롯

# %% [markdown]
# - 데이터 분포 파악
# - 데이터 관계 파악
# - 집단간 비교
# - 시간에 따른 변화

# %% [markdown]
# ---

# %% [markdown]
# ## 1. 데이터 분포(distribution) 파악

# %% [markdown]
# - 데이터의 중심(대표), 산포(퍼짐), 왜도, 첨도 등의 분포 특징을 파악하기 위해 사용
#
#
# - 히스토그램(histogram)
#     - matplotlib.pyplot.hist()
#     - seaborn.displot(kind='hist')
#     - seaborn.histplot()
#     - DataFrame.plot(kind='hist')
#     - DataFrame.plot.hist()

# %% [markdown]
# - 박스플롯(boxplot)
#     - matplotlib.pyplot.boxplot()
#     - seaborn.boxplot()
#     - DataFrame.plot(kind='box')
#     - DataFrame.plot.box()
#     - DataFrame.boxplot()

# %% [markdown]
# - 커널 밀도 곡선(Kernel Density Estimation plot)
#     - seaborn.displot(kind='kde')
#     - seaborn.kdeplot()
#     - DataFrame.plot(kind='kde')
#     - DataFrame.plot.kde()

# %% [markdown]
# #### 예제 데이터. iris dataset

# %%
iris = sns.load_dataset('iris')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.tail(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# ### 1) 히스토그램(histogram)
#
# - 표로 되어 있는 도수 분포를 그림으로 나타낸 것
# - 계급구간, 계급값, 빈도, 상대빈도

# %% [markdown]
# ### ① matplotlib.pyplot.hist()
#
# - 형식 : hist(x, bins=None, range=None, density=False, cumultive=False, ...)

# %%
plt.figure(figsize=(4,3))
plt.hist(iris.petal_length, bins=15)
plt.show()

# %% [markdown]
# ### ② pandas.DataFrame.hist()

# %%
iris.petal_length.plot.hist(bins=15, figsize=(4,3))
plt.show()

# %% [markdown]
# ### ③ seaborn의 히스토그램 함수
#
# - 형식1.
#     - seaborn.histplot(data, x, y, hue, weights, stat, bins, binwidth, kde, ...)
#     - 반환 : ax
#     - https://seaborn.pydata.org/generated/seaborn.histplot.html#seaborn.histplot
#
#
# - 형식2.
#     - displot(kind='hist', x, y, data, hue,...)
#     - https://seaborn.pydata.org/generated/seaborn.displot.html#seaborn.displot

# %% [markdown]
# ### sns.histplot()

# %%
sns.histplot(data=iris,x='petal_length')
plt.show()

# %%
sns.histplot(iris.petal_width)
plt.show()

# %%
sns.histplot(y= iris.petal_length, bins=15)
plt.show()

# %% [markdown]
# #### sns.histplot()의 stat인수
#
# - stat='count' : 각 빈의 관측값수
# - stat='frequency' : 각 빈의 너비로 나눈 관측값수
# - stat='probability' or 'proportion' : 막대 높이의 합이 1이 되도록 정규화
# - stat='percent' : 막대 높이 합이 100이 되도록 정규화
# - stat='density' : 히스토그램의 전체 면적이 1이 되도록 정규화

# %%
sns.histplot(iris.petal_width)
plt.show()

# %%
sns.histplot(iris.petal_width, stat='frequency')
plt.show()

# %%
sns.histplot(iris.petal_width, stat='percent')
plt.show()

# %%
sns.histplot(iris.petal_width, stat='probability')
plt.show()

# %% [markdown]
# #### sns.histplot(kde=True) 사용하여 커널 밀도 함수 곡선 그리기
# - 커널밀도곡선(Kernel Density Estimation curve)을 히스토그램 위에 그림

# %%
# kde=True -> 곡선 추가
sns.histplot(iris.sepal_length, kde=True, stat='frequency')
plt.show()

# %%
sns.histplot(iris.sepal_width, kde=True, stat='probability')
plt.show()

# %% [markdown]
# #### sns.histplot()의 cumulative인수

# %%
# cumulative=True -> 누적분포
sns.histplot(iris.sepal_length, cumulative=True, kde=True)
plt.show()

# %%
sns.histplot(iris.sepal_length, stat='frequency', cumulative=True, kde=True)
plt.show()

# %% [markdown]
# #### sns의 histplot()의 data인수만 지정할 경우
# - 수치형 데이터들에 대한 히스토그램을 모두 그림

# %%
# 수치형 데이터들을 한번에 그림
sns.histplot(iris)
plt.show()

# %%
sns.histplot(iris, kde=True)
plt.show()

# %% [markdown]
# #### sns의 histplot()의 hue인수에 범주형 데이터를 지정할 경우
# - 범주형 변수의 그룹별로 히스토그램을 그려 분포 비교 가능

# %%
# hue는 수치형 데이터가 아닌 범주형 데이터만 가능
sns.histplot(data=iris,x='petal_length', kde=True, hue='species')
plt.show()

# %% [markdown]
# #### sns의 histplot()의 element 인수 사용
#
# - element = 'step' : 계단모양으로 그림
# - element = 'poly' : 다각형으로 그림

# %%
# element='step' -> 계단 모양으로 표시
sns.histplot(data=iris,x='sepal_length', element='step', hue='species')
plt.show()

# %%
# element='poly' -> 다각형으로 표시
sns.histplot(data=iris, x='sepal_length', hue='species',kde=True,element='poly')
plt.show()

# %% [markdown]
# #### sns.histplot()의 multiple인수
#
# 두 변수가 지정된 경우만 사용
#
# - multiple='layer'
# - multiple='dodge'
# - multiple='stack'
# - multiple='fill'

# %%
# dodge -> 겹치지 않고 옆으로 막대그래프와 같은 형식으로 표기
sns.histplot(data=iris, x='sepal_length',hue='species', multiple='dodge')
plt.show()

# %%
# layer(default) -> 겹치게 표기
sns.histplot(data=iris, x='sepal_length',hue='species', multiple='layer')
plt.show()

# %%
# stack -> 겹치는 곳을 섞지 않고 위로 쌓는 형식으로 표기
sns.histplot(data=iris, x='sepal_length',hue='species', multiple='stack')
plt.show()

# %%
# fill -> x값마다 max()를 1로 두고 상대적인 크기 비교를 할 수 있게 표기
sns.histplot(data=iris, x='sepal_length',hue='species', multiple='fill')
plt.show()

# %% [markdown]
# ### sns.displot(kind='hist',)

# %%
sns.displot(kind='hist',data=iris,x='petal_length', hue='species')
plt.show()

# %%
sns.displot(kind='hist',data=iris,x='petal_length', hue='species', stat='probability', kde=True,element='poly')
plt.show()

# %%
sns.displot(kind='hist',data=iris,x='petal_length', hue='species', 
            stat='probability', kde=True,element='step', multiple='dodge')
plt.show()

# %%
# 2개의 변수를 사용하는 hist
sns.displot(data=iris,x='sepal_length',y='sepal_width', cbar=True)
plt.show()

# %% [markdown]
# ### 2) 박스플롯(boxplot)

# %% [markdown]
# - '상자 수염 그림'(box-and-whisker plot) 또는 '상자 그림'(box plot, boxplot)이라 부름
# - 수치적 자료를 표현하는 그래프
# - 자료로부터 얻어낸 통계량인 5가지 요약 수치(five-number summary)를 가지고 그린다
#     - 최소값
#     - 제1사분위(Q1, lower quartile)
#     - 제2사분위(Q2, median)
#     - 제3사분위(Q3, upper quartile)
#     - 최대값
#
# - 이상치 확인
# - 분포의 비대칭 확인

# %% [markdown]
# ### ① matplotlib.pyplot의 박스플롯 함수
#
# - 형식 : boxplot(x, notch, sym, vert, whis, widths, ...)

# %%
plt.boxplot(iris.sepal_length)
plt.show()

# %% [markdown]
# ---------------------------------------------

# %% [markdown]
# ### ② seaborn의 박스플롯 함수
#
# - 형식1.
#     - boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ... )
#
#     - 반환값 : ax (matplotlib Axes)
#
#
# - 형식2.
#     - catplot(kind='box', x=None, y=None, hue=None, data=None, ... )

# %%
sns.boxplot(data=iris, x='sepal_length')
plt.show()

# %% [markdown]
# #### sns.boxplot()의 data, x, y 인수
# - x : 범주(수치)형 변수
# - y : 수치(범주)형 변수
# - data : x,y에 지정한 변수를 가진 데이터프레임

# %%
sns.boxplot(data=iris, x='sepal_length', y='species')
plt.show()

# %%
sns.boxplot(iris)
plt.show()

# %% [markdown]
# #### sns.boxplot()의 order인수로 박스플롯 순서 변경

# %%
sns.boxplot(data=iris, x='sepal_length', y='species', order=['versicolor','virginica','setosa'])
plt.show()

# %% [markdown]
# #### sns.boxplot()의 orient인수로 박스플롯 방향 변경
# - orient = 'h' | 'v'

# %%
# orient= h -> 수평
sns.boxplot(iris, orient='h')
# Out:
# <Axes: >

# %%
# orient= v -> 수직
sns.boxplot(iris, orient='v')
# Out:
# <Axes: >

# %% [markdown]
# ### 3) 이변량 분포(bivariate distribution)
#
# - 이변량 자료 : 두 변수로 이루어진 분포

# %% [markdown]
# ### seaborn의 histplot()

# %%
sns.histplot(data=iris, x='petal_length', y='petal_width', cbar=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# ### seaborn의 displot()
#
# - 형식 : displot(x, y, data, ...)
# - https://seaborn.pydata.org/generated/seaborn.displot.html#seaborn.displot

# %%
# displot(kind= hist(default))
sns.displot(data=iris,x ='sepal_length', y='sepal_width')

# %%
# kind='kde' -> 등곡선
sns.displot(data=iris,x ='sepal_length', y='sepal_width', hue='species',
           palette='pastel', kind='kde')

# %%
sns.displot(data=iris,x ='sepal_length', y='sepal_width', hue='species',
           palette=['blue','red','green'], kind='kde')

# %%
# displot의 subplots -> col=
sns.displot(data=iris,x ='sepal_length', col='species')
plt.show()

# %%
sns.catplot(kind='box', data=iris, x='sepal_length',col='species')

# %% [markdown]
# #### 참고. seaborn.ecdfplot()

# %%
# 누적 분포 함수
sns.ecdfplot(data=iris, x='petal_length',hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='Proportion'>

# %% [markdown]
# ----

# %% [markdown]
# ## 2. 데이터의 관계 파악

# %% [markdown]
# - 변수간 상관성(선형성) 파악
# - 변수들간의 관계성 파악

# %% [markdown]
# - 산점도(scatter plot)
#     - matplotlib.pyplot.scatter()
#     - matplotlib.pyplot.plot()
#     - seaborn.scatterplot()
#     - seaborn.relplot(kind='scatter')
#     - seaborn.regplot()
#     - DataFrame.plot(kind='scatter')
#     - DataFrame.plot.scatter()

# %% [markdown]
# - 버블플롯(bubble plot)
#     - matplotlib.pyplot.scatter(, s= ,)
#     - seaborn.scatterplot(, size= ,)
#     - seaborn.relplot(kind='scatter', size= ,)

# %% [markdown]
# - 산점도행렬(scatterplot matrix)
#     - seaborn.pariplot()
#     - pandas.plotting.scatter_matrix()

# %% [markdown]
# ### 1) 산점도(scatter plot)
#
# - 두 변수간의 선형성 파악
# - 두 변수는 수치형 데이터

# %% [markdown]
# ### ① matplotlib.pyplot의 산점도 함수
#
# - 형식.
#     - scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, *, edgecolors=None, plotnonfinite=False, data=None,...)

# %%
plt.scatter(iris.sepal_length,iris.petal_length)
plt.show()

# %% [markdown]
# ### ② pandas의 plot.scatter() 함수이용하여 산점도 그리기

# %%
iris.plot.scatter(x='petal_length',y='petal_width')
plt.show()

# %% [markdown]
# ### ② seaborn의 산점도 함수
#
# - 형식1.
#     - scatterplot(x=None, y=None, hue=None, style=None, size=None, data=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, ... )
#     - https://seaborn.pydata.org/generated/seaborn.scatterplot.html#seaborn.scatterplot
#
#
# - 형식2.
#     - relplot(kind='scatter', x=None, y=None, hue=None, size=None, data=None, ... )
#     - https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot
#
#
# - 형식3.
#     - regplot(x=None, y=None, data=None, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95,...)
#     - https://seaborn.pydata.org/generated/seaborn.regplot.html#seaborn.regplot

# %% [markdown]
# ### sns.scatterplot()

# %%
sns.scatterplot(data=iris, x='sepal_length',y='petal_length')
plt.show()

# %% [markdown]
# #### sns.scatterplot()의 hue 인수
# - 범주형 변수의 범주에 따라 다른 색상으로 표시

# %%
sns.scatterplot(data=iris, x='sepal_length',y='petal_length',hue='species')
plt.show()

# %% [markdown]
# #### sns.scatterplot()의 style 인수
# - 범주형 변수의 범주에 따라 마커 모양을 다르게 표현

# %%
# style -> marker모양 변경
sns.scatterplot(data=iris, x='sepal_length',y='petal_length',hue='species',style='species')
plt.show()

# %% [markdown]
# #### sns.scatterplot()의 s인수로 마커 크기 변경

# %%
sns.scatterplot(data=iris, x='sepal_length',y='petal_length',hue='species',style='species',s=30)
plt.show()

# %% [markdown]
# #### scatterplot()함수의 alpha 인수를 이용하여 스타일 변경

# %%
sns.scatterplot(data=iris, x='sepal_length',y='petal_length',hue='species',style='species',s=30,
               alpha=0.5)
plt.show()

# %%
# size -> 크기를 나타내준다.
sns.scatterplot(data=iris, x='sepal_length',y='petal_length',hue='species',
                size='petal_width', alpha=0.5)
plt.show()

# %% [markdown]
# ### sns.relplot(kind='scatter')

# %%
sns.relplot(kind='scatter', data=iris,x='petal_length', y='petal_width')

# %%
sns.relplot(kind='scatter', data=iris,x='petal_length', y='petal_width', hue='species')

# %%
sns.relplot(kind='scatter', data=iris,x='petal_length', y='petal_width',style='species')

# %% [markdown]
# #### sns.scatterplot()의 palette 인수
#
# - seaborn에서 제공되는 팔레트 : https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette('dark')
# Out:
# [(0.0, 0.10980392156862745, 0.4980392156862745),
#  (0.6941176470588235, 0.25098039215686274, 0.050980392156862744),
#  (0.07058823529411765, 0.44313725490196076, 0.10980392156862745),
#  (0.5490196078431373, 0.03137254901960784, 0.0),
#  (0.34901960784313724, 0.11764705882352941, 0.44313725490196076),
#  (0.34901960784313724, 0.1843137254901961, 0.050980392156862744),
#  (0.6352941176470588, 0.20784313725490197, 0.5098039215686274),
#  (0.23529411764705882, 0.23529411764705882, 0.23529411764705882),
#  (0.7215686274509804, 0.5215686274509804, 0.0392156862745098),
#  (0.0, 0.38823529411764707, 0.4549019607843137)]

# %%
sns.relplot(kind='scatter', data=iris,x='petal_length', y='petal_width',hue='species',
           palette='dark')

# %% [markdown]
# - relplot()의 col인수

# %%
sns.relplot(kind='scatter', data=iris,x='petal_length', y='petal_width',style='species',col='species')

# %% [markdown]
# ### regplot()함수를 이용하여 산점도 그리기
# - 선형회귀 적합 선을 포함시키지 않으려면 fit_reg=False

# %%
sns.regplot(x=iris.petal_length, y=iris.petal_width)
plt.show()

# %%
sns.histplot(iris.petal_length, kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
# kde=True인 plot
sns.kdeplot(iris.petal_length)
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %% [markdown]
# ### 2) 산점도 행렬(scatter plot matrix) 그리기

# %% [markdown]
# - 여러 개의 연속형 변수에 대해서 두 변수씩 쌍을 이루는 산점도를 그려 한꺼번에 변수 간 관계를 일목요연하게 볼 수 있음

# %% [markdown]
# ###  ① seaborn.pairplot()을 이용한 산점도 행렬
#
# - 형식 : pairplot(data, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, corner=False, dropna=False, plot_kws=None, diag_kws=None, grid_kws=None, size=None)
#
#
# - https://seaborn.pydata.org/generated/seaborn.pairplot.html#seaborn.pairplot

# %% [markdown]
# #### pairplot()의 인수를 이용한 산점도 행렬1
# - diag_kind='hist'를 설정하여 대각원소 자리에 각 변수별 히스토그램 그리기

# %%
plt.figure(figsize=(3,3))
sns.pairplot(data=iris)
plt.show()

# %% [markdown]
# #### pairplot()의 인수를 이용한 산점도 행렬2
# - diag_kind='kde' : 각 변수별 커널밀도추정곡선 그림
# - hue='species' : 'species'(setosa, versicolor, virginica) 별로 색깔을 다르게 표시
# - 색깔은 palette 에 'bright', 'pastel', 'deep', 'muted', 'colorblind', 'dark' 중에서 가독성이 좋고 선호하는 색상으로 선택

# %%
sns.pairplot(iris,diag_kind='kde', hue='species')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.pairplot(iris,diag_kind='kde', hue='species',kind='kde')
plt.show()

# %% [markdown]
# ### ② pandas.plotting 의 scatter_matrix() 함수를 사용하여 산점도 행렬
#
# - 형식 : scatter_matrix(frame, alpha=0.5, figsize=None, ax=None, grid=False, diagonal='hist', marker='.', density_kwds=None, hist_kwds=None, range_padding=0.05, **kwargs)
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.plotting.scatter_matrix.html

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(iris)
plt.show()

# %%
scatter_matrix(iris, diagonal='kde')
plt.show()

# %% [markdown]
# ### 3) 버블 플롯
#
# - 산점도에서 x, y이외의 다른 변수를 포인트의 크기로 매핑하여 변수들간의 관계를 파악하게 함

# %% [markdown]
# ### ① matplotlib.pyplot의 scatter()를 이용한 버블플롯
#
# - scatter()의 s 인수 사용

# %%
size = iris.petal_length*10
colors=['r']*50+['g']*50+['b']*50
markers=['x']*50+['>']*50+['d']*50
plt.scatter(data=iris, x='sepal_length', y='sepal_width',s=size, c=colors, alpha=0.5)
plt.show()

# %%
sizes = iris.petal_length*10
colors = 'r g b'.split()
markers='d o ^'.split()
values=['setosa','versicolor','virginica']
for i in range(3):
    df = iris[iris.species == values[i]]
    x = df.sepal_length
    y = df.sepal_width
    s = df.petal_length*10
    plt.scatter(x,y,s=s,c=colors[i],marker=markers[i],label=values[i])
plt.legend()
plt.show()

# %% [markdown]
# ### ② seaborn의 산점도 함수를 이용한 버블 플롯
#
# - sns.scatterplot() 또는 relplot()의 size인수 사용

# %%
sns.scatterplot(data=iris,x='sepal_length',y='sepal_width', hue='species',size='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ------
