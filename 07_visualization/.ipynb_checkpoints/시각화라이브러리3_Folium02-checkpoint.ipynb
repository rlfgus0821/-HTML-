# %% [markdown]
# # folium

# %%
import numpy as np
import pandas as pd
import folium

# %% [markdown]
# ## 5. 지도에 마커(marker) 설정

# %% [markdown]
# - POI(Point Of Interest, 관심지점)을 추가하고 관련 정보 제공
# - 마커(marker) : 특정 위치를 표시하는 표식

# %% [markdown]
# ### 마커를 부착한 지도 생성

# %% [markdown]
# 단계1. 마커 생성
# - **folium.Marker(location=[위도,경도], popup='', tooltip='', icon=아이콘객체)**
#    - popup : 마커 클릭 시 표시되는 문구
#        - 환경에 따라 지원 안되는 경우도 있음
#    - tooltip : 마우스 hover시 표기되는 문구
#    - icon : Marker 형태 결정
#        - 기본값 : information icon
#
# 단계2. 마커 아이콘 생성
# - **folium.Icon(color='색상', icon='아이콘 모양')**
#
#
#
# 단계3. 마커 생성 후 부착
# - **folium.Marker().add_to(지도객체변수)**

# %% [markdown]
# #### Map 객체 생성

# %%
map1 = folium.Map(location=[37.56,127.05], zoom_start=8)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89923c40a9db8017782c330765f5bd07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89923c40a9db8017782c330765f5bd07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89923c40a9db8017782c330765f5bd07 = L.map(
#                 &quot;map_89923c40a9db8017782c330765f5bd07&quot;,
#                 {
#                     center: [37.56, 127.05],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfeceb11849ac2e5c17a788a108ea5ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cfeceb11849ac2e5c17a788a108ea5ec.addTo(map_89923c40a9db8017782c330765f5bd07);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Marker 객체 생성 및 Map에 부착

# %%
# 뚝섬역: 37.547433727420454, 127.04803964585416
# 과천서울대공원: 37.42769504509449, 127.01700374788183
# 카카오 판교: 37.39598490029507, 127.11053956708399

locs = {'뚝섬역': (37.547433727420454, 127.04803964585416),
        '과천서울대공원': (37.42769504509449, 127.01700374788183),
        '카카오 판교': (37.39598490029507, 127.11053956708399)}

# %%
folium.Marker((37.547433727420454, 127.04803964585416),
             popup='Subway',
             tooltip='뚝섬역',
             icon=folium.Icon(icon='cloud')).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89923c40a9db8017782c330765f5bd07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89923c40a9db8017782c330765f5bd07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89923c40a9db8017782c330765f5bd07 = L.map(
#                 &quot;map_89923c40a9db8017782c330765f5bd07&quot;,
#                 {
#                     center: [37.56, 127.05],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfeceb11849ac2e5c17a788a108ea5ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cfeceb11849ac2e5c17a788a108ea5ec.addTo(map_89923c40a9db8017782c330765f5bd07);
#
#
#             tile_layer_cfeceb11849ac2e5c17a788a108ea5ec.addTo(map_89923c40a9db8017782c330765f5bd07);
#
#
#             var marker_10d08e9e0b6f0126fe78fb9bd8f5c989 = L.marker(
#                 [37.547433727420454, 127.04803964585416],
#                 {}
#             ).addTo(map_89923c40a9db8017782c330765f5bd07);
#
#
#             var icon_bf5391647cf3a69d39cf50a14e440b4a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_10d08e9e0b6f0126fe78fb9bd8f5c989.setIcon(icon_bf5391647cf3a69d39cf50a14e440b4a);
#
#
#         var popup_8f0d58bac5ed6b802be688227a5e5f13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6485d9f27bde27e39afb17f1a66978ac = $(`&lt;div id=&quot;html_6485d9f27bde27e39afb17f1a66978ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Subway&lt;/div&gt;`)[0];
#                 popup_8f0d58bac5ed6b802be688227a5e5f13.setContent(html_6485d9f27bde27e39afb17f1a66978ac);
#
#
#
#         marker_10d08e9e0b6f0126fe78fb9bd8f5c989.bindPopup(popup_8f0d58bac5ed6b802be688227a5e5f13)
#         ;
#
#
#
#
#             marker_10d08e9e0b6f0126fe78fb9bd8f5c989.bindTooltip(
#                 `&lt;div&gt;
#                      뚝섬역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for name,loc in locs.items():
    folium.Marker(loc,
             popup=name,
             tooltip=name,
             icon=folium.Icon(icon='cloud')).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89923c40a9db8017782c330765f5bd07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89923c40a9db8017782c330765f5bd07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89923c40a9db8017782c330765f5bd07 = L.map(
#                 &quot;map_89923c40a9db8017782c330765f5bd07&quot;,
#                 {
#                     center: [37.56, 127.05],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfeceb11849ac2e5c17a788a108ea5ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cfeceb11849ac2e5c17a788a108ea5ec.addTo(map_89923c40a9db8017782c330765f5bd07);
#
#
#             tile_layer_cfeceb11849ac2e5c17a788a108ea5ec.addTo(map_89923c40a9db8017782c330765f5bd07);
#
#
#             var marker_10d08e9e0b6f0126fe78fb9bd8f5c989 = L.marker(
#                 [37.547433727420454, 127.04803964585416],
#                 {}
#             ).addTo(map_89923c40a9db8017782c330765f5bd07);
#
#
#             var icon_bf5391647cf3a69d39cf50a14e440b4a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_10d08e9e0b6f0126fe78fb9bd8f5c989.setIcon(icon_bf5391647cf3a69d39cf50a14e440b4a);
#
#
#         var popup_8f0d58bac5ed6b802be688227a5e5f13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6485d9f27bde27e39afb17f1a66978ac = $(`&lt;div id=&quot;html_6485d9f27bde27e39afb17f1a66978ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Subway&lt;/div&gt;`)[0];
#                 popup_8f0d58bac5ed6b802be688227a5e5f13.setContent(html_6485d9f27bde27e39afb17f1a66978ac);
#
#
#
#         marker_10d08e9e0b6f0126fe78fb9bd8f5c989.bindPopup(popup_8f0d58bac5ed6b802be688227a5e5f13)
#         ;
#
#
#
#
#             marker_10d08e9e0b6f0126fe78fb9bd8f5c989.bindTooltip(
#                 `&lt;div&gt;
#                      뚝섬역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_cfeceb11849ac2e5c17a788a108ea5ec.addTo(map_89923c40a9db8017782c330765f5bd07);
#
#
#             var marker_2365b8d6dd4288bec09ee03ad2d313b1 = L.marker(
#                 [37.547433727420454, 127.04803964585416],
#                 {}
#             ).addTo(map_89923c40a9db8017782c330765f5bd07);
#
#
#             var icon_38b676c18ca27e7b18491e2c5c351021 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2365b8d6dd4288bec09ee03ad2d313b1.setIcon(icon_38b676c18ca27e7b18491e2c5c351021);
#
#
#         var popup_3f3656a246944e5410f92a35932e7865 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0089cbdae096743caf7d378bff606359 = $(`&lt;div id=&quot;html_0089cbdae096743caf7d378bff606359&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;뚝섬역&lt;/div&gt;`)[0];
#                 popup_3f3656a246944e5410f92a35932e7865.setContent(html_0089cbdae096743caf7d378bff606359);
#
#
#
#         marker_2365b8d6dd4288bec09ee03ad2d313b1.bindPopup(popup_3f3656a246944e5410f92a35932e7865)
#         ;
#
#
#
#
#             marker_2365b8d6dd4288bec09ee03ad2d313b1.bindTooltip(
#                 `&lt;div&gt;
#                      뚝섬역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_602b9d5489717954b0bbc806dbf3fec2 = L.marker(
#                 [37.42769504509449, 127.01700374788183],
#                 {}
#             ).addTo(map_89923c40a9db8017782c330765f5bd07);
#
#
#             var icon_4158b188ee20a81bdf99327e6f54a74a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_602b9d5489717954b0bbc806dbf3fec2.setIcon(icon_4158b188ee20a81bdf99327e6f54a74a);
#
#
#         var popup_45ea7d2273b69840957133ac5d8ebaea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9f93d49c5d29b6983a7f81cf0e7b162 = $(`&lt;div id=&quot;html_e9f93d49c5d29b6983a7f81cf0e7b162&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;과천서울대공원&lt;/div&gt;`)[0];

# %% [markdown]
# ### 마커 클릭 시 특정 사이트로 이동하기

# %%
lat, lon = [37.40,127.09]
map2 = folium.Map(location=[lat,lon], zoom_start=8)
folium.TileLayer(tiles='Stamen Terrain').add_to(map2)
folium.Marker(location=(37.42769504509449, 127.01700374788183),
             popup='<a href="https://grandpark.seoul.go.kr/main/ko.do" target=_blank>과천서울대공원</a>',
             tooltip='과천서울대공원',
             icon=folium.Icon(icon='info-sign')).add_to(map2)

folium.Marker(location=(37.39598490029507, 127.11053956708399),
             popup='<a href="https://www.google.com/maps/place/%EC%B9%B4%EC%B9%B4%EC%98%A4+%ED%8C%90%EA%B5%90%EC%95%84%EC%A7%80%ED%8A%B8/@37.3957122,127.1105181,15z/data=!4m2!3m1!1s0x0:0x8bd4531be8ce5df4?sa=X&ved=1t:2428&ictx=111" target=_blank>카카오 판교</a>',
             tooltip='카카오 판교',
             icon=folium.Icon(icon='info-sign')).add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7347f46d8434936376e3e174c2f951f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7347f46d8434936376e3e174c2f951f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7347f46d8434936376e3e174c2f951f2 = L.map(
#                 &quot;map_7347f46d8434936376e3e174c2f951f2&quot;,
#                 {
#                     center: [37.4, 127.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62c8dfab12780c973ee59dfb5f7b3905 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_62c8dfab12780c973ee59dfb5f7b3905.addTo(map_7347f46d8434936376e3e174c2f951f2);
#
#
#             var tile_layer_a666d1ff23c5ae0fa1100460de575068 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a666d1ff23c5ae0fa1100460de575068.addTo(map_7347f46d8434936376e3e174c2f951f2);
#
#
#             var marker_c6c0304ddc616e4321bc7ee6e0cc8c3f = L.marker(
#                 [37.42769504509449, 127.01700374788183],
#                 {}
#             ).addTo(map_7347f46d8434936376e3e174c2f951f2);
#
#
#             var icon_4bcddef9d0154ea02cbe45b514390cb9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c6c0304ddc616e4321bc7ee6e0cc8c3f.setIcon(icon_4bcddef9d0154ea02cbe45b514390cb9);
#
#
#         var popup_8d30bb4876605a7470f530d1941cd057 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93d1b12dc09690f9aef4d726d6035655 = $(`&lt;div id=&quot;html_93d1b12dc09690f9aef4d726d6035655&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://grandpark.seoul.go.kr/main/ko.do&quot; target=_blank&gt;과천서울대공원&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_8d30bb4876605a7470f530d1941cd057.setContent(html_93d1b12dc09690f9aef4d726d6035655);
#
#
#
#         marker_c6c0304ddc616e4321bc7ee6e0cc8c3f.bindPopup(popup_8d30bb4876605a7470f530d1941cd057)
#         ;
#
#
#
#
#             marker_c6c0304ddc616e4321bc7ee6e0cc8c3f.bindTooltip(
#                 `&lt;div&gt;
#                      과천서울대공원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bd44d1dd6d8459a683eb2aac90f68bce = L.marker(
#                 [37.39598490029507, 127.11053956708399],
#                 {}
#             ).addTo(map_7347f46d8434936376e3e174c2f951f2);
#
#
#             var icon_4533ab0ad509578451af9e48a425b366 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bd44d1dd6d8459a683eb2aac90f68bce.setIcon(icon_4533ab0ad509578451af9e48a425b366);
#
#
#         var popup_5f3c47fc5f034c9a6a29c3d8ef8dc38b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5a6dc3a59602d2dc52416a5cbea682b = $(`&lt;div id=&quot;html_c5a6dc3a59602d2dc52416a5cbea682b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.google.com/maps/place/%EC%B9%B4%EC%B9%B4%EC%98%A4+%ED%8C%90%EA%B5%90%EC%95%84%EC%A7%80%ED%8A%B8/@37.3957122,127.1105181,15z/data=!4m2!3m1!1s0x0:0x8bd4531be8ce5df4?sa=X&amp;ved=1t:2428&amp;ictx=111&quot; target=_blank&gt;카카오 판교&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_5f3c47fc5f034c9a6a29c3d8ef8dc38b.setContent(html_c5a6dc3a59602d2dc52416a5cbea682b);
#
#
#
#         marker_bd44d1dd6d8459a683eb2aac90f68bce.bindPopup(popup_5f3c47fc5f034c9a6a29c3d8ef8dc38b)
#         ;
#
#
#
#
#             marker_bd44d1dd6d8459a683eb2aac90f68bce.bindTooltip(
#                 `&lt;div&gt;
#                      카카오 판교
#                  &lt;/div&g

# %% [markdown]
# ### 마커에 custom icon 적용하기

# %% [markdown]
# - icon옵션 custom
#     - prefix 옵션 : 두 가지 - fa, glyphicon
#     - prefix='fa' 옵션을 선택할 때 icon 선택하는 사이트
#         - https://fontawesome.com/
#     - prefix = 'glyphicon' 옵션을 선택할 때 icon 선택하는 사이트
#         - http://bootstrapk.com/components/

# %%
lat, lon = [37.40,127.09]
zoom_size= 11

icon = folium.Icon(color='green', icon='info-sign')

map3 = folium.Map(location=[lat,lon], zoom_start=zoom_size)
folium.TileLayer(tiles='Stamen Terrain').add_to(map3)

folium.Marker(location=(37.42769504509449, 127.01700374788183),
             popup='<a href="https://grandpark.seoul.go.kr/main/ko.do" target=_blank>과천서울대공원</a>',
             tooltip='과천서울대공원',
             icon=icon).add_to(map3)

#prefix(출처)
folium.Marker(location=(37.39598490029507, 127.11053956708399),
             popup='<a href="https://www.google.com/maps/place/%EC%B9%B4%EC%B9%B4%EC%98%A4+%ED%8C%90%EA%B5%90%EC%95%84%EC%A7%80%ED%8A%B8/@37.3957122,127.1105181,15z/data=!4m2!3m1!1s0x0:0x8bd4531be8ce5df4?sa=X&ved=1t:2428&ictx=111" target=_blank>카카오 판교</a>',
             tooltip='카카오 판교',
             icon=folium.Icon(color='orange',icon='building', prefix='fa')).add_to(map3)

folium.Marker(location=(37.547433727420454, 127.04803964585416),
             popup= '<a href="https://grandpark.seoul.go.kr/main/ko.do" target=_blank>뚝섬역</a>',
             tooltip='뚝섬역',
             icon=folium.Icon(icon='info-sign')).add_to(map3)
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad2bcf4f0236f1ca8af4fd78f213a6b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad2bcf4f0236f1ca8af4fd78f213a6b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad2bcf4f0236f1ca8af4fd78f213a6b9 = L.map(
#                 &quot;map_ad2bcf4f0236f1ca8af4fd78f213a6b9&quot;,
#                 {
#                     center: [37.4, 127.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d73ba33c4f98d87c6706a82789452cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3d73ba33c4f98d87c6706a82789452cd.addTo(map_ad2bcf4f0236f1ca8af4fd78f213a6b9);
#
#
#             var tile_layer_4615b4f43a725ee8711b4ac7fa38c19f = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4615b4f43a725ee8711b4ac7fa38c19f.addTo(map_ad2bcf4f0236f1ca8af4fd78f213a6b9);
#
#
#             var marker_fe21bf5404018228e9036b741213a403 = L.marker(
#                 [37.42769504509449, 127.01700374788183],
#                 {}
#             ).addTo(map_ad2bcf4f0236f1ca8af4fd78f213a6b9);
#
#
#             var icon_45f823771a22361d09e2a6ff528f29f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fe21bf5404018228e9036b741213a403.setIcon(icon_45f823771a22361d09e2a6ff528f29f8);
#
#
#         var popup_5a75280c6baf51f2fd90dc4f01b27c56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e1442714a25efde12e8ca7f89a571613 = $(`&lt;div id=&quot;html_e1442714a25efde12e8ca7f89a571613&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://grandpark.seoul.go.kr/main/ko.do&quot; target=_blank&gt;과천서울대공원&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_5a75280c6baf51f2fd90dc4f01b27c56.setContent(html_e1442714a25efde12e8ca7f89a571613);
#
#
#
#         marker_fe21bf5404018228e9036b741213a403.bindPopup(popup_5a75280c6baf51f2fd90dc4f01b27c56)
#         ;
#
#
#
#
#             marker_fe21bf5404018228e9036b741213a403.bindTooltip(
#                 `&lt;div&gt;
#                      과천서울대공원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6476237a4bf75e87b2d7c97d73977ccb = L.marker(
#                 [37.39598490029507, 127.11053956708399],
#                 {}
#             ).addTo(map_ad2bcf4f0236f1ca8af4fd78f213a6b9);
#
#
#             var icon_9dbc32162e87acbf0606c44d4d25873f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6476237a4bf75e87b2d7c97d73977ccb.setIcon(icon_9dbc32162e87acbf0606c44d4d25873f);
#
#
#         var popup_c80a54de9d274c9f548ff58cf750e4d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_226bd5c0fc8fcfbae3f5e6f670f7a474 = $(`&lt;div id=&quot;html_226bd5c0fc8fcfbae3f5e6f670f7a474&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.google.com/maps/place/%EC%B9%B4%EC%B9%B4%EC%98%A4+%ED%8C%90%EA%B5%90%EC%95%84%EC%A7%80%ED%8A%B8/@37.3957122,127.1105181,15z/data=!4m2!3m1!1s0x0:0x8bd4531be8ce5df4?sa=X&amp;ved=1t:2428&amp;ictx=111&quot; target=_blank&gt;카카오 판교&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_c80a54de9d274c9f548ff58cf750e4d6.setContent(html_226bd5c0fc8fcfbae3f5e6f670f7a474);
#
#
#
#         marker_6476237a4bf75e87b2d7c97d73977ccb.bindPopup(popup_c80a54de9d274c9f548ff58cf750e4d6)
#         ;
#
#
#
#
#             marker_6476237a4bf75e87b2d7c97d73977ccb.bindTooltip(
#                 `&lt;div&gt;
#                      카카오 판교
#                  &lt;/div&gt;`,

# %% [markdown]
# ### 문제
#
# 1. 수원역에 있는 에이케이플라자를 지도에 표시
#
#
# 2. icon은 검정색, 건물모양으로 표시
#   - color = 'black'
#   - icon = 'building'
#   - prefix = 'fa'
#
#
# 3. 아이콘에 마우스를 올리면 AK플라자 글씨를 나타나게 함
#
#
# 4. 아이콘 클릭 시 AK플라자 사이트로 연결
#     - http://www.akplaza.com/main.do

# %%
lat, lon = (37.266774, 127.030401)
zoom_size= 11

icon = folium.Icon(color='black', icon='building', prefix='fa')

maps = folium.Map(location=[lat,lon], zoom_start=zoom_size)
folium.TileLayer(tiles='Stamen Terrain').add_to(maps)

folium.Marker(location=[lat, lon],
             popup='<a href="http://www.akplaza.com/main.do" target=_blank>수원AK플라자</a>',
             tooltip='수원 AK플라자',
             icon=icon).add_to(maps)
maps
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10994e9129d7bb1288fc0349290ad7b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10994e9129d7bb1288fc0349290ad7b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10994e9129d7bb1288fc0349290ad7b0 = L.map(
#                 &quot;map_10994e9129d7bb1288fc0349290ad7b0&quot;,
#                 {
#                     center: [37.266774, 127.030401],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61bceeb30b7acd537c9066b603f55f13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_61bceeb30b7acd537c9066b603f55f13.addTo(map_10994e9129d7bb1288fc0349290ad7b0);
#
#
#             var tile_layer_ae0d104e7a0df73681043fb964233ebc = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ae0d104e7a0df73681043fb964233ebc.addTo(map_10994e9129d7bb1288fc0349290ad7b0);
#
#
#             var marker_d93fea277863ba842a3b4dc5d4107004 = L.marker(
#                 [37.266774, 127.030401],
#                 {}
#             ).addTo(map_10994e9129d7bb1288fc0349290ad7b0);
#
#
#             var icon_ba7752a5c6e178e6dc127c6439c2a1c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d93fea277863ba842a3b4dc5d4107004.setIcon(icon_ba7752a5c6e178e6dc127c6439c2a1c6);
#
#
#         var popup_2c41e191b29882e50e2bf57aca7c2037 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b7ee194c421a907ff70c5861975cbc1 = $(`&lt;div id=&quot;html_4b7ee194c421a907ff70c5861975cbc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;http://www.akplaza.com/main.do&quot; target=_blank&gt;수원AK플라자&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_2c41e191b29882e50e2bf57aca7c2037.setContent(html_4b7ee194c421a907ff70c5861975cbc1);
#
#
#
#         marker_d93fea277863ba842a3b4dc5d4107004.bindPopup(popup_2c41e191b29882e50e2bf57aca7c2037)
#         ;
#
#
#
#
#             marker_d93fea277863ba842a3b4dc5d4107004.bindTooltip(
#                 `&lt;div&gt;
#                      수원 AK플라자
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 6. 지도에 원 그리기

# %% [markdown]
# : 지도에 데이터 값, 영역 등의 정보를 표현하기 위한 방법
#
# - folium.Circle()
# - folium.CircleMarker()

# %% [markdown]
# #### Circle()  생성

# %%
lat, lon = 37.54, 127.05469
zoom_size= 15
m = folium.Map(location=[lat,lon], zoom_start=zoom_size)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0485d89636ceab1c064c6e7ecb8b1923 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0485d89636ceab1c064c6e7ecb8b1923&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0485d89636ceab1c064c6e7ecb8b1923 = L.map(
#                 &quot;map_0485d89636ceab1c064c6e7ecb8b1923&quot;,
#                 {
#                     center: [37.54, 127.05469],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6144c2355bd36d2cadc5456e0d40e1b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6144c2355bd36d2cadc5456e0d40e1b7.addTo(map_0485d89636ceab1c064c6e7ecb8b1923);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# circle
lat, lon = 37.54, 127.05469
zoom_size= 15
m = folium.Map(location=[lat,lon], zoom_start=zoom_size)
folium.Circle(location=[lat,lon],radius = 100, color='red', fill_color='green',
             popup='Circle popup',
             tooltip='Circle tooltip').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_307ec8ed758792ffabe7ad835f05821f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_307ec8ed758792ffabe7ad835f05821f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_307ec8ed758792ffabe7ad835f05821f = L.map(
#                 &quot;map_307ec8ed758792ffabe7ad835f05821f&quot;,
#                 {
#                     center: [37.54, 127.05469],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83f1c68fa6620cfc9a49e1c17be6e9e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_83f1c68fa6620cfc9a49e1c17be6e9e0.addTo(map_307ec8ed758792ffabe7ad835f05821f);
#
#
#             var circle_02b4a5a77a1c1ebe9088642aba620846 = L.circle(
#                 [37.54, 127.05469],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_307ec8ed758792ffabe7ad835f05821f);
#
#
#         var popup_1daaa4b09a9857e2a537f7931840dc48 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9073b838a71e8d3b28f2730d73c1db31 = $(`&lt;div id=&quot;html_9073b838a71e8d3b28f2730d73c1db31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Circle popup&lt;/div&gt;`)[0];
#                 popup_1daaa4b09a9857e2a537f7931840dc48.setContent(html_9073b838a71e8d3b28f2730d73c1db31);
#
#
#
#         circle_02b4a5a77a1c1ebe9088642aba620846.bindPopup(popup_1daaa4b09a9857e2a537f7931840dc48)
#         ;
#
#
#
#
#             circle_02b4a5a77a1c1ebe9088642aba620846.bindTooltip(
#                 `&lt;div&gt;
#                      Circle tooltip
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### CircleMarker 생성

# %%
# circleMarker -> 줌을 해도 써클의 크기가 유지가 된다
lat, lon = 37.54, 127.05469
zoom_size= 15
m = folium.Map(location=[lat,lon], zoom_start=zoom_size)
folium.CircleMarker(location=[lat,lon],radius = 100, color='#34ebc6', fill_color='#c634eb',
             popup='CircleMarker popup',
             tooltip='CircleMarker tooltip').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_365394a70c8e0e2a20be3888478dc609 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_365394a70c8e0e2a20be3888478dc609&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_365394a70c8e0e2a20be3888478dc609 = L.map(
#                 &quot;map_365394a70c8e0e2a20be3888478dc609&quot;,
#                 {
#                     center: [37.54, 127.05469],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be38bfbf1e318197d2223eacabeee54b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_be38bfbf1e318197d2223eacabeee54b.addTo(map_365394a70c8e0e2a20be3888478dc609);
#
#
#             var circle_marker_551d9948bcdf46725ec1d8eac2eef251 = L.circleMarker(
#                 [37.54, 127.05469],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#34ebc6&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c634eb&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_365394a70c8e0e2a20be3888478dc609);
#
#
#         var popup_43e898bedb9e9b63a3d90ed27bb56845 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_810d30911447f7dd9ef62c2a136880cb = $(`&lt;div id=&quot;html_810d30911447f7dd9ef62c2a136880cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CircleMarker popup&lt;/div&gt;`)[0];
#                 popup_43e898bedb9e9b63a3d90ed27bb56845.setContent(html_810d30911447f7dd9ef62c2a136880cb);
#
#
#
#         circle_marker_551d9948bcdf46725ec1d8eac2eef251.bindPopup(popup_43e898bedb9e9b63a3d90ed27bb56845)
#         ;
#
#
#
#
#             circle_marker_551d9948bcdf46725ec1d8eac2eef251.bindTooltip(
#                 `&lt;div&gt;
#                      CircleMarker tooltip
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 7. MarkerCluster 생성
#
# - 가까운 거리의 Marker들을 그룹화하여 Marker의 개수로 표현
# - folium.plugin의 MarkerCluster클래스
# - https://python-visualization.github.io/folium/latest/user_guide/plugins/marker_cluster.html#MarkerCluster

# %% [markdown]
# ### MarkerCluster 추가 방법
#
# 1. Map 객체 생성
# 2. MarkerCluster 객체 생성하여 Map에 추가
# 3. MarkerCluster 객체에 Marker 추가

# %%
# 서울시 구청 위치 정보
gu_loc = {'강남구청':[37.52579, 127.0483],
        '서초구청':[37.49093, 127.0329],
        '동작구청':[37.51871, 126.9364],
        '구로구청':[37.50237, 126.8890],
        '양천구청' :[37.52007, 126.9549],
        '영등포구청': [37.54240, 126.8402],
        '관악구청': [37.48467, 126.9515],
        '용산구청' :[37.53804, 126.9913],
        '서대문구청': [37.58567, 126.9357],
        '마포구청' : [37.57003, 126.9019],
        '은평구청' : [37.60675, 126.9302],
        '종로구청' : [37.57615, 126.9790],
        '중구청' : [37.56798, 126.9975],
        '성북구청' : [37.59342, 127.0172],
        '동대문구청' : [37.57792, 127.0401],
        '중랑구청' : [37.60961, 127.0931],
        '노원구청' : [37.65664, 127.0559],
        '도봉구청' : [37.67214, 127.0462],
        '강북구청' : [37.64278, 127.0253],
        '광진구청' : [37.54104, 127.0826],
        '강동구청' : [37.53246, 127.1237],
        '송파구청' : [37.51803, 127.105]
       }

# %% [markdown]
# - map 객체 생성

# %%
lat, lon = 37.56668940479636,126.97863915872446
tiles = 'https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png'
attr = 'Stadia Maps'
mapgu = folium.Map(location=[lat, lon],
                   tiles=tiles, attr=attr)

for name,loc in gu_loc.items():
    folium.Marker(loc,
             popup=name,tooltip=name,
             icon=folium.Icon(icon='cloud')).add_to(mapgu)
mapgu
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03f53e327d7cadc3931788e97fac52aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03f53e327d7cadc3931788e97fac52aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03f53e327d7cadc3931788e97fac52aa = L.map(
#                 &quot;map_03f53e327d7cadc3931788e97fac52aa&quot;,
#                 {
#                     center: [37.56668940479636, 126.97863915872446],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e42bb25d715e33ac3e509738ef0e4c1 = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Stadia Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0e42bb25d715e33ac3e509738ef0e4c1.addTo(map_03f53e327d7cadc3931788e97fac52aa);
#
#
#             var marker_8e682d95513d45dd8b943555ba3f72c5 = L.marker(
#                 [37.52579, 127.0483],
#                 {}
#             ).addTo(map_03f53e327d7cadc3931788e97fac52aa);
#
#
#             var icon_9c99b6674337864329bff5d0f75e7192 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8e682d95513d45dd8b943555ba3f72c5.setIcon(icon_9c99b6674337864329bff5d0f75e7192);
#
#
#         var popup_1edec6b676e8ac3c12c18dc3e9d9603f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0244c302417896301fb5d3a778123bf8 = $(`&lt;div id=&quot;html_0244c302417896301fb5d3a778123bf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구청&lt;/div&gt;`)[0];
#                 popup_1edec6b676e8ac3c12c18dc3e9d9603f.setContent(html_0244c302417896301fb5d3a778123bf8);
#
#
#
#         marker_8e682d95513d45dd8b943555ba3f72c5.bindPopup(popup_1edec6b676e8ac3c12c18dc3e9d9603f)
#         ;
#
#
#
#
#             marker_8e682d95513d45dd8b943555ba3f72c5.bindTooltip(
#                 `&lt;div&gt;
#                      강남구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_467ca1f0178d6ba063f74930825267ce = L.marker(
#                 [37.49093, 127.0329],
#                 {}
#             ).addTo(map_03f53e327d7cadc3931788e97fac52aa);
#
#
#             var icon_015d6b3494c7446f66840169dc3e0864 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_467ca1f0178d6ba063f74930825267ce.setIcon(icon_015d6b3494c7446f66840169dc3e0864);
#
#
#         var popup_836f6ab92711a1e8126caaf26cab017d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fea14bd0f4458277c5ce2a5c423d3985 = $(`&lt;div id=&quot;html_fea14bd0f4458277c5ce2a5c423d3985&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서초구청&lt;/div&gt;`)[0];
#                 popup_836f6ab92711a1e8126caaf26cab017d.setContent(html_fea14bd0f4458277c5ce2a5c423d3985);
#
#
#
#         marker_467ca1f0178d6ba063f74930825267ce.bindPopup(popup_836f6ab92711a1e8126caaf26cab017d)
#         ;
#
#
#
#
#             marker_467ca1f0178d6ba063f74930825267ce.bindTooltip(
#                 `&lt;div&gt;
#                      서초구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ef3551dc30d0cfe52d4533d6dc49d28e = L.marker(
#                 [37.51871, 126.9364],
#                 {}
#             ).addTo(map_03f53e327d7cadc3931788e97fac52aa);
#
#
#             var icon_9d7fa6cf764eee0fb3b51d5af3c011d5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef3551dc30d0cfe52d4533d6dc49d28e.setIcon(icon_9d7fa6cf764eee0fb3b51d5af3c011d5);
#
#
#         var popup_880b471dac6660e98d82b3ca0959809e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_566ef89d32c9ebb084dad10f3bb8abaa = $(`&lt;div id=&quot;html_566ef89d32c9ebb084dad10f3bb8abaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;동작구청&lt;/div&gt;`)[0];
#                 popup_880b471dac6660e98d82b3ca0959809e.setContent(html_566ef89d32c9ebb084dad10f3bb8abaa);
#
#
#
#         marker_ef3551dc30d0cfe52d4533d6dc49d28e.bindPopup(popup_880b471dac6660e98d82b3ca0959809e)
#         ;
#
#
#
#
#             marker_ef3551dc30d0cfe52d4533d6dc49d28e.bindTooltip(
#                 `&lt;div&gt;
#                      동

# %% [markdown]
# #### MarkerCluster 추가

# %%
from folium.plugins import MarkerCluster

# %%
# Map() 객체 생성
lat, lon = 37.56668940479636,126.97863915872446
tiles = 'https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png'
attr = 'Stadia Maps'
mapgu = folium.Map(location=[lat, lon],
                   tiles=tiles, attr=attr)
# MarkerCluster 객체 생성하여 Map에 추가
marker_cluster = MarkerCluster().add_to(mapgu)

# Maker를 MarkerCluster에 붙이기
for name,loc in gu_loc.items():
    folium.Marker(loc,
             popup=name,tooltip=name,
             icon=folium.Icon(icon='cloud')).add_to(marker_cluster)
mapgu
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bab93a08cb7c04391105ef47e7c63bc5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bab93a08cb7c04391105ef47e7c63bc5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bab93a08cb7c04391105ef47e7c63bc5 = L.map(
#                 &quot;map_bab93a08cb7c04391105ef47e7c63bc5&quot;,
#                 {
#                     center: [37.56668940479636, 126.97863915872446],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e88e9e85cd4ffc3660d63ee187986ae6 = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Stadia Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e88e9e85cd4ffc3660d63ee187986ae6.addTo(map_bab93a08cb7c04391105ef47e7c63bc5);
#
#
#             var marker_cluster_855c6668de20f481f029721eb6709617 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_80286e3d4be79a48c8327c1abf1de59a = L.marker(
#                 [37.52579, 127.0483],
#                 {}
#             ).addTo(marker_cluster_855c6668de20f481f029721eb6709617);
#
#
#             var icon_36987c88c25386ce814276b042ee8a25 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_80286e3d4be79a48c8327c1abf1de59a.setIcon(icon_36987c88c25386ce814276b042ee8a25);
#
#
#         var popup_16fbfa126a12fda330cb34077585d7a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_612168409937cf514d40dae9bf4b46c8 = $(`&lt;div id=&quot;html_612168409937cf514d40dae9bf4b46c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구청&lt;/div&gt;`)[0];
#                 popup_16fbfa126a12fda330cb34077585d7a0.setContent(html_612168409937cf514d40dae9bf4b46c8);
#
#
#
#         marker_80286e3d4be79a48c8327c1abf1de59a.bindPopup(popup_16fbfa126a12fda330cb34077585d7a0)
#         ;
#
#
#
#
#             marker_80286e3d4be79a48c8327c1abf1de59a.bindTooltip(
#                 `&lt;div&gt;
#                      강남구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f528231bba9679e717653fe6f2599cd6 = L.marker(
#                 [37.49093, 127.0329],
#                 {}
#             ).addTo(marker_cluster_855c6668de20f481f029721eb6709617);
#
#
#             var icon_92c4fd84a3d4a7f5a183e8f765dace77 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f528231bba9679e717653fe6f2599cd6.setIcon(icon_92c4fd84a3d4a7f5a183e8f765dace77);
#
#
#         var popup_f2998c3e3ea1eb762a4a84a17b44f1b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63ef6e89cb061bbb82bbaf31781b9cc7 = $(`&lt;div id=&quot;html_63ef6e89cb061bbb82bbaf31781b9cc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서초구청&lt;/div&gt;`)[0];
#                 popup_f2998c3e3ea1eb762a4a84a17b44f1b2.setContent(html_63ef6e89cb061bbb82bbaf31781b9cc7);
#
#
#
#         marker_f528231bba9679e717653fe6f2599cd6.bindPopup(popup_f2998c3e3ea1eb762a4a84a17b44f1b2)
#         ;
#
#
#
#
#             marker_f528231bba9679e717653fe6f2599cd6.bindTooltip(
#                 `&lt;div&gt;
#                      서초구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7b9f1958cf62bc383a95bb4e3d47aee6 = L.marker(
#                 [37.51871, 126.9364],
#                 {}
#             ).addTo(marker_cluster_855c6668de20f481f029721eb6709617);
#
#
#             var icon_2d7d36effb0ea79605a507ffaac1cd84 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7b9f1958cf62bc383a95bb4e3d47aee6.setIcon(icon_2d7d36effb0ea79605a507ffaac1cd84);
#
#
#         var popup_79360bffc6c4acf61565f0d7fe20b76c = L.popup({&quot;maxWidth&quot;: &q

# %% [markdown]
# ### 각 구의 구청 위치에 Marker를 표시

# %%
# Map() 객체 생성
lat, lon = 37.56668940479636,126.97863915872446
tiles = 'https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png'
attr = 'Stadia Maps'
mapgu1 = folium.Map(location=[lat, lon],
                   tiles=tiles, attr=attr)
# MarkerCluster 객체 생성하여 Map에 추가
marker_cluster = MarkerCluster().add_to(mapgu1)

# Maker를 MarkerCluster에 붙이기
for name,loc in gu_loc.items():
    folium.Marker(loc,
             popup=folium.Popup(name, max_width=200),tooltip=name).add_to(marker_cluster)
mapgu1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_863d048088d2dde3f2eb725071982c47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_863d048088d2dde3f2eb725071982c47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_863d048088d2dde3f2eb725071982c47 = L.map(
#                 &quot;map_863d048088d2dde3f2eb725071982c47&quot;,
#                 {
#                     center: [37.56668940479636, 126.97863915872446],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c420c8550840de5cc44d1a6e7e717f7a = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Stadia Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c420c8550840de5cc44d1a6e7e717f7a.addTo(map_863d048088d2dde3f2eb725071982c47);
#
#
#             var marker_cluster_b4d1071bccf1c4be9788420013eb4cd4 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_11b2b352bd94253b506800b96ec413c3 = L.marker(
#                 [37.52579, 127.0483],
#                 {}
#             ).addTo(marker_cluster_b4d1071bccf1c4be9788420013eb4cd4);
#
#
#         var popup_49c66fdafcd98dfb1be9ddfed49d32d9 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_7607df21f4e9edf9f43686eb4a2e3e66 = $(`&lt;div id=&quot;html_7607df21f4e9edf9f43686eb4a2e3e66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구청&lt;/div&gt;`)[0];
#                 popup_49c66fdafcd98dfb1be9ddfed49d32d9.setContent(html_7607df21f4e9edf9f43686eb4a2e3e66);
#
#
#
#         marker_11b2b352bd94253b506800b96ec413c3.bindPopup(popup_49c66fdafcd98dfb1be9ddfed49d32d9)
#         ;
#
#
#
#
#             marker_11b2b352bd94253b506800b96ec413c3.bindTooltip(
#                 `&lt;div&gt;
#                      강남구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_53ac646d4a4bf600886892fbeb13c883 = L.marker(
#                 [37.49093, 127.0329],
#                 {}
#             ).addTo(marker_cluster_b4d1071bccf1c4be9788420013eb4cd4);
#
#
#         var popup_5b56939846d61e8f769b5daa95a14739 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_7afaea8a6fdb1fe66a98c4935a8d7681 = $(`&lt;div id=&quot;html_7afaea8a6fdb1fe66a98c4935a8d7681&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서초구청&lt;/div&gt;`)[0];
#                 popup_5b56939846d61e8f769b5daa95a14739.setContent(html_7afaea8a6fdb1fe66a98c4935a8d7681);
#
#
#
#         marker_53ac646d4a4bf600886892fbeb13c883.bindPopup(popup_5b56939846d61e8f769b5daa95a14739)
#         ;
#
#
#
#
#             marker_53ac646d4a4bf600886892fbeb13c883.bindTooltip(
#                 `&lt;div&gt;
#                      서초구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c4430438258dfe4d563339bab304f0d3 = L.marker(
#                 [37.51871, 126.9364],
#                 {}
#             ).addTo(marker_cluster_b4d1071bccf1c4be9788420013eb4cd4);
#
#
#         var popup_16fc96b2b07bb6d2db15201efbace253 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_cf932e9a62e9be54c1b3186acea7f1bd = $(`&lt;div id=&quot;html_cf932e9a62e9be54c1b3186acea7f1bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;동작구청&lt;/div&gt;`)[0];
#                 popup_16fc96b2b07bb6d2db15201efbace253.setContent(html_cf932e9a62e9be54c1b3186acea7f1bd);
#
#
#
#         marker_c4430438258dfe4d563339bab304f0d3.bindPopup(popup_16fc96b2b07bb6d2db15201efbace253)
#         ;
#
#
#
#
#             marker_c4430438258dfe4d563339bab304f0d3.bindTooltip(
#                 `&lt;div&gt;
#                      동작구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4793ba418c9c5e36cae211b38d007d1b = L.marker(
#                 [37.50237, 126.889],
#                 {}
#             ).addTo(marker_cluster_b4d1071bccf1c4be9788420013eb4cd4);
#
#
#         var popup_939d4f3a524cbca20bbbce0df7e89736 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_14f75d0220b4da97512b4ef2201ca4bd = $(`&lt;div id=&quot;html_14f75d0220b4da97512b4ef2201ca4bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;구로구청&lt;/div&gt;`)[0];
#                 popup_939d4f3a524cbca20bbbce0df7e89736.setContent(html_14f75d0220b4da97512b4ef2201ca4bd);

# %% [markdown]
# -----

# %% [markdown]
# ### 연습문제. 서울시 지진대피소 위치를 MarkerCluster 표시하기

# %% [markdown]
# - 데이터 : 서울시 지진옥외대피소
# - 대피소별 주소, 면적, 표값 제공(좌표계: 위경도(GPS), XY좌표(GRS90-중부원점))
# - 출처 : 서울시 열린데이터 광장
# - https://data.seoul.go.kr/dataList/OA-21063/S/1/datasetView.do

# %% [markdown]
# ------
